# %% [markdown]
# You can press shift + enter to quickly advance through each line of a notebook. Try it now!

# %% [markdown]
# This snippet of Python creates an extremely simple graph and runs.

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf

import time
import os
import math
import numpy
import numpy as np
import random
from PIL import Image
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Basic model parameters as external flags.
# this is an interesting way of setting up constants
# syntax is flags.define_<type_of_variable>(variable_name, value, description)
flags = tf.app.flags
FLAGS = flags.FLAGS
flags.DEFINE_float('learning_rate', 0.001, 'Initial learning rate.')
flags.DEFINE_integer('max_steps', 12000, 'Number of steps to run trainer.')
flags.DEFINE_integer('batch_size', 50, 'Batch size.  '
                     'Must divide evenly into the dataset sizes.')
flags.DEFINE_string('train_checkpoint', 'data', 'checkpoint saver prefix')

NUM_CLASSES = 10
IMAGE_SIZE = 28
CHANNELS = 1
IMAGE_PIXELS = IMAGE_SIZE * IMAGE_SIZE * CHANNELS
#NUMBER_OF_INPUTS=8 #now determined by direct counting

# Get the sets of images and labels for training, validation, and
train_images = []
train_labels = []

training_image_paths = []
training_image_numbers = []
labels = []

image_reader = tf.WholeFileReader()

# %%
"""start get image paths"""

def get_image_paths_in_folder(folder_name):
  image_paths = [os.path.join(folder, pic)
      for folder, subs, pics, in os.walk(".")
      for pic in pics if pic.endswith(".png") and folder.startswith(folder_name)]
  return image_paths

for x in xrange(NUM_CLASSES):
  training_image_paths.append(get_image_paths_in_folder("./mnist_png/testing/" + str(x)))


#append all images to a single array
for x in xrange(NUM_CLASSES):
  for filename in training_image_paths[x]:
    image = Image.open(filename)
    image = image.resize((IMAGE_SIZE,IMAGE_SIZE))
    train_images.append(np.array(image))

#get the lengths of each into an array
for x in xrange(NUM_CLASSES):
  training_image_numbers.append(len(training_image_paths[x]))

"""end get image paths"""
# Out:
# 'end get image paths'

# %%
#start getting labels in format

for x in xrange(NUM_CLASSES):
  labels += [x]*training_image_numbers[x]

train_labels = np.array(labels)


NUMBER_OF_INPUTS = len(train_images)

train_images = np.array(train_images)
train_images = train_images.reshape(NUMBER_OF_INPUTS,IMAGE_PIXELS)

# %%
#dataset class for feeding next batch
class DataSet(object):
  train_images = []
  train_labels = []
  batch_index = 0
  batch_size = 1
  last_index = 0

  def __init__(self, train_images, train_labels, batch_size):
    self.train_images = train_images
    self.train_labels = train_labels
    self.batch_size = batch_size
    self.batch_index = 0
    self.last_index = len(train_labels) - 1

  def next_batch(self):
    temp_batch_index = self.batch_index
    start_index = temp_batch_index * self.batch_size
    #end index is one batch ahead of start
    end_index = (temp_batch_index + 1 ) * self.batch_size

    # if within bounds, send over the labels and images
    if end_index <= self.last_index:
      self.batch_index += 1
      return self.train_images[start_index:end_index], self.train_labels[start_index:end_index]
    # else if out of bounds, then wrap around
    # TODO is this where we mark an epoch?
    else:
      self.batch_index = 0
      temp_batch_index = self.batch_index
      start_index = self.batch_index * self.batch_size
      end_index = (self.batch_index + 1 ) * self.batch_size
      return self.train_images[start_index:end_index], self.train_labels[start_index:end_index]

#create data_set object similar to way in which MNIST example was created
data_set = DataSet(train_images, train_labels, FLAGS.batch_size)


test_images, test_labels = data_set.next_batch()

# %%
def weight_variable(shape):
  initial = tf.truncated_normal(shape, stddev=0.1)
  return tf.Variable(initial)

def bias_variable(shape):
  initial = tf.constant(0.1, shape=shape)
  return tf.Variable(initial)

def conv2d(x, W):
  return tf.nn.conv2d(x, W, strides=[1,1,1,1], padding='SAME')

def max_pool_2x2(x):
  return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')

# %%
def inference(images):

  # Convolutional - 1
  with tf.name_scope('h_conv_1'):
    W_conv_1 = weight_variable([5,5,1,32])
    b_conv_1 = bias_variable([32])

    x_image = tf.reshape(images, [-1,28,28, 1])
    h_conv_1 = tf.nn.relu(conv2d(x_image, W_conv_1) + b_conv_1)

    # Max pool 2x2 - 1
    h_pool_1 = max_pool_2x2(h_conv_1)
  # Convolutional - 2
  with tf.name_scope('h_conv_2'):
    W_conv_2 = weight_variable([5,5,32,64])
    b_conv_2 = bias_variable([64])

    h_conv_2 = tf.nn.relu(conv2d(h_pool_1, W_conv_2) + b_conv_2)

    # Max pool 2x2 - 1
    h_pool_2 = max_pool_2x2(h_conv_2)

  # Densely connected 1
  with tf.name_scope('densely_connected_1'):
    W_fc1 = weight_variable([7 * 7 * 64, 1024])
    b_fc1 = bias_variable([1024])

    h_pool_2_flat = tf.reshape(h_pool_2, [-1, 7*7*64])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool_2_flat, W_fc1) + b_fc1)

    #keep_prob = tf.constant(0.2, dtype=tf.float32)
    #h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)
  # Readout Layer
  with tf.name_scope('softmax_linear'):
    W_fc2 = weight_variable([1024, 10])
    b_fc2 = bias_variable([10])

    logits = tf.matmul(h_fc1, W_fc2) + b_fc2

  return logits

# %%
def cal_loss(logits, labels):
  labels = tf.to_int64(labels)
  cross_entropy = tf.nn.sparse_softmax_cross_entropy_with_logits(logits, labels, name='xentropy')
  loss = tf.reduce_mean(cross_entropy, name='xentropy_mean')
  return loss

def training(loss, learning_rate):
  optimizer = tf.train.AdamOptimizer(learning_rate)
  global_step = tf.Variable(0, name='global_step', trainable=False)
  train_op = optimizer.minimize(loss, global_step=global_step)
  return train_op

def evaluation(logits, labels):
  correct = tf.nn.in_top_k(logits, labels, 1)
  return tf.reduce_sum(tf.cast(correct, tf.int32))

def placeholder_inputs(batch_size):
  images_placeholder = tf.placeholder(tf.float32, shape=[batch_size,IMAGE_PIXELS])
  labels_placeholder = tf.placeholder(tf.int32, shape=[batch_size])
  return images_placeholder, labels_placeholder

# %%
def fill_feed_dict(data_set, images_pl, labels_pl):

  images_feed, labels_feed = data_set.next_batch()

  feed_dict = {
      images_pl: images_feed,
      labels_pl: labels_feed
  }
  return feed_dict

def do_eval(sess,
            eval_correct,
            images_placeholder, labels_placeholder,
            data_set):
  # And run one epoch of eval.
  true_count = 0  # Counts the number of correct predictions.
  steps_per_epoch = NUMBER_OF_INPUTS // FLAGS.batch_size
  num_examples = steps_per_epoch * FLAGS.batch_size
  for step in xrange(steps_per_epoch):
    feed_dict = fill_feed_dict(data_set,
                               images_placeholder,
                               labels_placeholder)
    true_count += sess.run(eval_correct, feed_dict=feed_dict)
  precision = true_count / num_examples
  print('  Num examples: %d  Num correct: %d  Precision @1.00: %0.04f' %
        (num_examples, true_count, precision))

# %%
def run_training():
  # Tell TensorFlow that the model will be built into the default Graph.
  with tf.Graph().as_default():
    # Generate placeholders for the images and labels.
    images_placeholder, labels_placeholder = placeholder_inputs(FLAGS.batch_size)

    # Build a Graph that computes predictions from the inference model.
    logits = inference(images_placeholder)

    # Add to the Graph the Ops for loss calculation.
    loss = cal_loss(logits, labels_placeholder)

    # Add to the Graph the Ops that calculate and apply gradients.
    train_op = training(loss, FLAGS.learning_rate)

    # Add the Op to compare the logits to the labels during evaluation.
    eval_correct = evaluation(logits, labels_placeholder)

    # Create a saver for writing training checkpoints.
    saver = tf.train.Saver()

    # Create a session for running Ops on the Graph.
    sess = tf.Session()

    # Run the Op to initialize the variables.
    init = tf.initialize_all_variables()
    sess.run(init)

    # And then after everything is built, start the training loop.
    for step in xrange(FLAGS.max_steps):
      start_time = time.time()

      feed_dict = fill_feed_dict(data_set,images_placeholder,labels_placeholder)

      _, loss_value = sess.run([train_op, loss],
                               feed_dict=feed_dict)

      duration = time.time() - start_time

      if step % 2 == 0:
        # Print status to stdout.
        print('Step %d: loss = %.2f (%.3f sec)' % (step, loss_value, duration))

      if (step + 1) % 1000 == 0 or (step + 1) == FLAGS.max_steps:
        saver.save(sess, FLAGS.train_checkpoint, global_step=step)
        print('Training Data Eval:')
        do_eval(sess,
                eval_correct,
                images_placeholder,
                labels_placeholder,
                data_set)

# %%
run_training()
# Out:
# Step 0: loss = 3431.66 (0.201 sec)
# Step 2: loss = 0.00 (0.007 sec)
# Step 4: loss = 0.00 (0.007 sec)
# Step 6: loss = 0.00 (0.007 sec)
# Step 8: loss = 0.00 (0.007 sec)
# Step 10: loss = 0.00 (0.007 sec)
# Step 12: loss = 0.00 (0.007 sec)
# Step 14: loss = 0.00 (0.007 sec)
# Step 16: loss = 0.00 (0.007 sec)
# Step 18: loss = 7094.34 (0.007 sec)
# Step 20: loss = 10398.85 (0.007 sec)
# Step 22: loss = 3244.24 (0.007 sec)
# Step 24: loss = 0.00 (0.007 sec)
# Step 26: loss = 0.00 (0.007 sec)
# Step 28: loss = 0.00 (0.008 sec)
# Step 30: loss = 0.00 (0.007 sec)
# Step 32: loss = 0.00 (0.007 sec)
# Step 34: loss = 0.00 (0.007 sec)
# Step 36: loss = 0.00 (0.007 sec)
# Step 38: loss = 0.00 (0.007 sec)
# Step 40: loss = 0.00 (0.007 sec)
# Step 42: loss = 9265.07 (0.007 sec)
# Step 44: loss = 5309.98 (0.007 sec)
# Step 46: loss = 1767.67 (0.007 sec)
# Step 48: loss = 4.33 (0.007 sec)
# Step 50: loss = 0.00 (0.008 sec)
# Step 52: loss = 0.00 (0.008 sec)
# Step 54: loss = 0.00 (0.008 sec)
# Step 56: loss = 0.00 (0.008 sec)
# Step 58: loss = 0.00 (0.008 sec)
# Step 60: loss = 0.00 (0.008 sec)
# Step 62: loss = 975.99 (0.008 sec)
# Step 64: loss = 597.31 (0.008 sec)
# Step 66: loss = 247.99 (0.008 sec)
# Step 68: loss = 41.39 (0.008 sec)
# Step 70: loss = 0.03 (0.008 sec)
# Step 72: loss = 0.00 (0.007 sec)
# Step 74: loss = 0.00 (0.007 sec)
# Step 76: loss = 0.00 (0.008 sec)
# Step 78: loss = 0.00 (0.008 sec)
# Step 80: loss = 0.00 (0.008 sec)
# Step 82: loss = 229.11 (0.008 sec)
# Step 84: loss = 198.93 (0.008 sec)
# Step 86: loss = 101.61 (0.008 sec)
# Step 88: loss = 29.97 (0.007 sec)
# Step 90: loss = 1.71 (0.007 sec)
# Step 92: loss = 0.66 (0.007 sec)
# Step 94: loss = 0.00 (0.007 sec)
# Step 96: loss = 0.00 (0.007 sec)
# Step 98: loss = 0.00 (0.007 sec)
# Step 100: loss = 0.00 (0.007 sec)
# Step 102: loss = 91.71 (0.007 sec)
# Step 104: loss = 57.97 (0.007 sec)
# Step 106: loss = 33.06 (0.007 sec)
# Step 108: loss = 16.01 (0.007 sec)
# Step 110: loss = 6.87 (0.007 sec)
# Step 112: loss = 2.28 (0.007 sec)
# Step 114: loss = 1.31 (0.007 sec)
# Step 116: loss = 0.03 (0.007 sec)
# Step 118: loss = 0.00 (0.007 sec)
# Step 120: loss = 61.14 (0.007 sec)
# Step 122: loss = 48.52 (0.007 sec)
# Step 124: loss = 35.06 (0.008 sec)
# Step 126: loss = 17.72 (0.007 sec)
# Step 128: loss = 5.30 (0.008 sec)
# Step 130: loss = 0.79 (0.008 sec)
# Step 132: loss = 0.23 (0.008 sec)
# Step 134: loss = 0.10 (0.008 sec)
# Step 136: loss = 0.00 (0.007 sec)
# Step 138: loss = 6.81 (0.007 sec)
# Step 140: loss = 28.68 (0.007 sec)
# Step 142: loss = 21.30 (0.008 sec)
# Step 144: loss = 13.58 (0.007 sec)
# Step 146: loss = 6.50 (0.008 sec)
# Step 148: loss = 0.90 (0.008 sec)
# Step 150: loss = 0.39 (0.008 sec)
# Step 152: loss = 0.38 (0.008 sec)
# Step 154: loss = 0.21 (0.008 sec)
# Step 156: loss = 0.01 (0.008 sec)
# Step 158: loss = 0.00 (0.008 sec)
# Step 160: loss = 22.01 (0.008 sec)
# Step 162: loss = 18.80 (0.008 sec)
# Step 164: loss = 18.15 (0.007 sec)
# Step 166: loss = 14.01 (0.007 sec)
# Step 168: loss = 12.56 (0.009 sec)
# Step 170: loss = 9.81 (0.007 sec)
# Step 172: loss = 6.79 (0.007 sec)
# Step 174: loss = 4.88 (0.007 sec)
# Step 176: loss = 4.30 (0.007 sec)
# Step 178: loss = 5.35 (0.007 sec)
# Step 180: loss = 14.97 (0.007 sec)
# Step 182: loss = 14.06 (0.007 sec)
# Step 184: loss = 10.80 (0.007 sec)
# Step 186: loss = 9.39 (0.007 sec)
# Step 188: loss = 7.50 (0.007 sec)
# Step 190: loss = 6.50 (0.007 sec)
# Step 192: loss = 5.27 (0.007 sec)
# Step 194: loss = 4.68 (0.007 sec)
# Step 196: loss = 3.54 (0.007 sec)
# Step 198: loss = 6.31 (0.007 sec)
# Step 200: loss = 5.70 (0.009 sec)
# Step 202: loss = 5.21 (0.007 sec)
# Step 204: loss = 4.78 (0.007 sec)
# Step 206: loss = 4.47 (0.007 sec)
# Step 208: loss = 3.68 (0.007 sec)
# Step 210: loss = 3.27 (0.008 sec)
# Step 212: loss = 3.03 (0.008 sec)
# Step 214: loss = 2.76 (0.008 sec)
# Step 216: loss = 2.45 (0.008 sec)
# Step 218: loss = 6.18 (0.008 sec)
# Step 220: loss = 8.96 (0.008 sec)
# Step 222: loss = 7.44 (0.007 sec)
# Step 224: loss = 5.18 (0.008 sec)
# Step 226: loss = 5.11 (0.007 sec)
# Step 228: loss = 3.90 (0.008 sec)
# Step 230: loss = 4.15 (0.008 sec)
# Step 232: loss = 3.65 (0.008 sec)
# Step 234: loss = 3.28 (0.008 sec)
# Step 236: loss = 2.79 (0.008 sec)
# Step 238: loss = 2.63 (0.008 sec)
# Step 240: loss = 2.10 (0.007 sec)
# Step 242: loss = 4.27 (0.007 sec)
# Step 244: loss = 4.13 (0.007 sec)
# Step 246: loss = 3.81 (0.007 sec)
# Step 248: loss = 3.66 (0.007 sec)
# Step 250: loss = 3.25 (0.007 sec)
# Step 252: loss = 3.13 (0.007 sec)
# Step 254: loss = 2.93 (0.007 sec)
# Step 256: loss = 2.54 (0.008 sec)
# Step 258: loss = 2.27 (0.007 sec)
# Step 260: loss = 2.14 (0.007 sec)
# Step 262: loss = 2.71 (0.007 sec)
# Step 264: loss = 2.82 (0.007 sec)
# Step 266: loss = 2.74 (0.007 sec)
# Step 268: loss = 2.56 (0.007 sec)
# Step 270: loss = 2.26 (0.007 sec)
# Step 272: loss = 2.29 (0.007 sec)
# Step 274: loss = 2.01 (0.007 sec)
# Step 276: loss = 1.73 (0.007 sec)
# Step 278: loss = 1.46 (0.007 sec)
# Step 280: loss = 1.01 (0.007 sec)
# Step 282: loss = 2.22 (0.007 sec)
# Step 284: loss = 2.27 (0.007 sec)
# Step 286: loss = 1.98 (0.007 sec)
# Step 288: loss = 1.71 (0.007 sec)
# Step 290: loss = 1.20 (0.007 sec)
# Step 292: loss = 0.73 (0.007 sec)
# Step 294: loss = 0.83 (0.007 sec)
# Step 296: loss = 0.45 (0.007 sec)
# Step 298: loss = 0.24 (0.007 sec)
# Step 300: loss = 0.21 (0.007 sec)
# Step 302: loss = 6.66 (0.007 sec)
# Step 304: loss = 4.32 (0.007 sec)
# Step 306: loss = 2.92 (0.007 sec)
# Step 308: loss = 1.41 (0.008 sec)
# Step 310: loss = 1.00 (0.007 sec)
# Step 312: loss = 0.67 (0.007 sec)
# Step 314: loss = 0.46 (0.008 sec)
# Step 316: loss = 0.12 (0.007 sec)
# Step 318: loss = 0.01 (0.007 sec)
# Step 320: loss = 10.60 (0.007 sec)
# Step 322: loss = 3.67 (0.007 sec)
# Step 324: loss = 2.27 (0.007 sec)
# Step 326: loss = 1.96 (0.007 sec)
# Step 328: loss = 1.17 (0.007 sec)
# Step 330: loss = 0.98 (0.007 sec)
# Step 332: loss = 0.77 (0.008 sec)
# Step 334: loss = 0.39 (0.007 sec)
# Step 336: loss = 0.23 (0.007 sec)
# Step 338: loss = 1.47 (0.007 sec)
# Step 340: loss = 5.74 (0.007 sec)
# Step 342: loss = 4.11 (0.007 sec)
# Step 344: loss = 3.05 (0.008 sec)
# Step 346: loss = 2.81 (0.008 sec)
# Step 348: loss = 1.36 (0.007 sec)
# Step 350: loss = 1.46 (0.007 sec)
# Step 352: loss = 1.16 (0.007 sec)
# Step 354: loss = 1.03 (0.007 sec)
# Step 356: loss = 0.42 (0.007 sec)
# Step 358: loss = 0.25 (0.007 sec)
# Step 360: loss = 6.92 (0.007 sec)
# Step 362: loss = 5.64 (0.007 sec)
# Step 364: loss = 3.70 (0.007 sec)
# Step 366: loss = 3.38 (0.007 sec)
# Step 368: loss = 2.58 (0.007 sec)
# Step 370: loss = 2.30 (0.007 sec)
# Step 372: loss = 2.00 (0.007 sec)
# Step 374: loss = 1.79 (0.007 sec)
# Step 376: loss = 1.46 (0.007 sec)
# Step 378: loss = 1.76 (0.007 sec)
# Step 380: loss = 3.22 (0.007 sec)
# Step 382: loss = 2.26 (0.007 sec)
# Step 384: loss = 1.93 (0.007 sec)
# Step 386: loss = 1.70 (0.007 sec)
# Step 388: loss = 1.24 (0.007 sec)
# Step 390: loss = 1.65 (0.007 sec)
# Step 392: loss = 1.16 (0.007 sec)
# Step 394: loss = 1.01 (0.007 sec)
# Step 396: loss = 0.85 (0.007 sec)
# Step 398: loss = 2.79 (0.007 sec)
# Step 400: loss = 2.54 (0.007 sec)
# Step 402: loss = 2.19 (0.007 sec)
# Step 404: loss = 1.99 (0.007 sec)
# Step 406: loss = 1.28 (0.007 sec)
# Step 408: loss = 1.07 (0.007 sec)
# Step 410: loss = 1.05 (0.007 sec)
# Step 412: loss = 0.74 (0.007 sec)
# Step 414: loss = 0.63 (0.007 sec)
# Step 416: loss = 0.58 (0.007 sec)
# Step 418: loss = 1.72 (0.007 sec)
# Step 420: loss = 2.60 (0.007 sec)
# Step 422: loss = 2.29 (0.007 sec)
# Step 424: loss = 1.98 (0.007 sec)
# Step 426: loss = 2.11 (0.007 sec)
# Step 428: loss = 1.92 (0.007 sec)
# Step 430: loss = 1.70 (0.008 sec)
# Step 432: loss = 1.52 (0.007 sec)
# Step 434: loss = 1.44 (0.008 sec)
# Step 436: loss = 1.14 (0.007 sec)
# Step 438: loss = 1.21 (0.007 sec)
# Step 440: loss = 0.84 (0.007 sec)
# Step 442: loss = 4.21 (0.007 sec)
# Step 444: loss = 4.37 (0.007 sec)
# Step 446: loss = 3.77 (0.007 sec)
# Step 448: loss = 2.79 (0.007 sec)
# Step 450: loss = 2.17 (0.007 sec)
# Step 452: loss = 2.21 (0.007 sec)
# Step 454: loss = 1.97 (0.007 sec)
# Step 456: loss = 1.45 (0.007 sec)
# Step 458: loss = 1.27 (0.007 sec)
# Step 460: loss = 1.17 (0.007 sec)
# Step 462: loss = 3.09 (0.007 sec)
# Step 464: loss = 3.13 (0.007 sec)
# Step 466: loss = 3.04 (0.007 sec)
# Step 468: loss = 2.72 (0.007 sec)
# Step 470: loss = 2.49 (0.007 sec)
# Step 472: loss = 2.44 (0.007 sec)
# Step 474: loss = 2.23 (0.007 sec)
# Step 476: loss = 2.05 (0.007 sec)
# Step 478: loss = 1.77 (0.007 sec)
# Step 480: loss = 1.57 (0.007 sec)
# Step 482: loss = 2.42 (0.007 sec)
# Step 484: loss = 2.53 (0.007 sec)
# Step 486: loss = 2.19 (0.007 sec)
# Step 488: loss = 1.86 (0.007 sec)
# Step 490: loss = 1.51 (0.007 sec)
# Step 492: loss = 1.09 (0.007 sec)
# Step 494: loss = 0.89 (0.007 sec)
# Step 496: loss = 0.56 (0.007 sec)
# Step 498: loss = 0.25 (0.007 sec)
# Step 500: loss = 0.30 (0.007 sec)
# Step 502: loss = 3.71 (0.007 sec)
# Step 504: loss = 3.53 (0.007 sec)
# Step 506: loss = 2.76 (0.007 sec)
# Step 508: loss = 2.36 (0.007 sec)
# Step 510: loss = 1.60 (0.007 sec)
# Step 512: loss = 1.70 (0.007 sec)
# Step 514: loss = 1.35 (0.007 sec)
# Step 516: loss = 0.63 (0.007 sec)
# Step 518: loss = 0.36 (0.007 sec)
# Step 520: loss = 3.40 (0.008 sec)
# Step 522: loss = 2.25 (0.007 sec)
# Step 524: loss = 1.18 (0.007 sec)
# Step 526: loss = 0.63 (0.008 sec)
# Step 528: loss = 0.21 (0.007 sec)
# Step 530: loss = 0.19 (0.007 sec)
# Step 532: loss = 0.29 (0.007 sec)
# Step 534: loss = 0.07 (0.008 sec)
# Step 536: loss = 0.03 (0.007 sec)
# Step 538: loss = 1.12 (0.007 sec)
# Step 540: loss = 3.60 (0.008 sec)
# Step 542: loss = 2.93 (0.008 sec)
# Step 544: loss = 2.12 (0.008 sec)
# Step 546: loss = 1.09 (0.008 sec)
# Step 548: loss = 0.12 (0.008 sec)
# Step 550: loss = 0.17 (0.008 sec)
# Step 552: loss = 0.07 (0.007 sec)
# Step 554: loss = 0.05 (0.007 sec)
# Step 556: loss = 0.11 (0.007 sec)
# Step 558: loss = 0.10 (0.007 sec)
# Step 560: loss = 8.57 (0.008 sec)
# Step 562: loss = 6.66 (0.007 sec)
# Step 564: loss = 2.85 (0.008 sec)
# Step 566: loss = 2.12 (0.007 sec)
# Step 568: loss = 1.52 (0.007 sec)
# Step 570: loss = 1.40 (0.007 sec)
# Step 572: loss = 1.37 (0.007 sec)
# Step 574: loss = 0.99 (0.007 sec)
# Step 576: loss = 0.83 (0.007 sec)
# Step 578: loss = 0.86 (0.007 sec)
# Step 580: loss = 2.65 (0.007 sec)
# Step 582: loss = 2.01 (0.008 sec)
# Step 584: loss = 1.79 (0.007 sec)
# Step 586: loss = 1.29 (0.007 sec)
# Step 588: loss = 0.78 (0.007 sec)
# Step 590: loss = 0.61 (0.007 sec)
# Step 592: loss = 0.53 (0.007 sec)
# Step 594: loss = 0.30 (0.007 sec)
# Step 596: loss = 0.24 (0.007 sec)
# Step 598: loss = 5.03 (0.007 sec)
# Step 600: loss = 4.20 (0.007 sec)
# Step 602: loss = 3.27 (0.008 sec)
# Step 604: loss = 2.57 (0.008 sec)
# Step 606: loss = 1.96 (0.009 sec)
# Step 608: loss = 1.70 (0.008 sec)
# Step 610: loss = 1.21 (0.008 sec)
# Step 612: loss = 1.11 (0.008 sec)
# Step 614: loss = 0.86 (0.008 sec)
# Step 616: loss = 0.59 (0.008 sec)
# Step 618: loss = 1.20 (0.007 sec)
# Step 620: loss = 1.75 (0.007 sec)
# Step 622: loss = 1.66 (0.007 sec)
# Step 624: loss = 1.48 (0.007 sec)
# Step 626: loss = 1.56 (0.007 sec)
# Step 628: loss = 1.32 (0.008 sec)
# Step 630: loss = 1.34 (0.008 sec)
# Step 632: loss = 1.20 (0.008 sec)
# Step 634: loss = 0.98 (0.009 sec)
# Step 636: loss = 0.84 (0.008 sec)
# Step 638: loss = 0.90 (0.007 sec)
# Step 640: loss = 0.65 (0.007 sec)
# Step 642: loss = 3.54 (0.007 sec)
# Step 644: loss = 3.46 (0.007 sec)
# Step 646: loss = 2.54 (0.007 sec)
# Step 648: loss = 2.33 (0.007 sec)
# Step 650: loss = 1.99 (0.008 sec)
# Step 652: loss = 1.70 (0.009 sec)
# Step 654: loss = 1.53 (0.008 sec)
# Step 656: loss = 0.91 (0.008 sec)
# Step 658: loss = 0.76 (0.008 sec)
# Step 660: loss = 0.75 (0.008 sec)
# Step 662: loss = 3.07 (0.009 sec)
# Step 664: loss = 3.00 (0.007 sec)
# Step 666: loss = 3.10 (0.007 sec)
# Step 668: loss = 2.59 (0.007 sec)
# Step 670: loss = 2.70 (0.007 sec)
# Step 672: loss = 2.39 (0.007 sec)
# Step 674: loss = 2.08 (0.008 sec)
# Step 676: loss = 1.92 (0.008 sec)
# Step 678: loss = 1.57 (0.008 sec)
# Step 680: loss = 1.33 (0.009 sec)
# Step 682: loss = 2.67 (0.008 sec)
# Step 684: loss = 2.58 (0.009 sec)
# Step 686: loss = 2.02 (0.008 sec)
# Step 688: loss = 1.87 (0.007 sec)
# Step 690: loss = 1.42 (0.007 sec)
# Step 692: loss = 0.81 (0.007 sec)
# Step 694: loss = 0.57 (0.007 sec)
# Step 696: loss = 0.20 (0.008 sec)
# Step 698: loss = 0.19 (0.007 sec)
# Step 700: loss = 0.19 (0.008 sec)
# Step 702: loss = 4.55 (0.008 sec)
# Step 704: loss = 2.79 (0.008 sec)
# Step 706: loss = 1.51 (0.008 sec)
# Step 708: loss = 1.03 (0.008 sec)
# Step 710: loss = 0.54 (0.007 sec)
# Step 712: loss = 0.29 (0.007 sec)
# Step 714: loss = 0.28 (0.007 sec)
# Step 716: loss = 0.12 (0.007 sec)
# Step 718: loss = 0.07 (0.007 sec)
# Step 720: loss = 13.28 (0.007 sec)
# Step 722: loss = 5.44 (0.008 sec)
# Step 724: loss = 1.52 (0.008 sec)
# Step 726: loss = 0.44 (0.008 sec)
# Step 728: loss = 0.01 (0.008 sec)
# Step 730: loss = 0.02 (0.007 sec)
# Step 732: loss = 0.61 (0.007 sec)
# Step 734: loss = 0.00 (0.007 sec)
# Step 736: loss = 0.00 (0.007 sec)
# Step 738: loss = 1.55 (0.007 sec)
# Step 740: loss = 5.81 (0.008 sec)
# Step 742: loss = 2.69 (0.008 sec)
# Step 744: loss = 1.53 (0.008 sec)
# Step 746: loss = 0.62 (0.008 sec)
# Step 748: loss = 0.46 (0.008 sec)
# Step 750: loss = 0.10 (0.009 sec)
# Step 752: loss = 0.30 (0.007 sec)
# Step 754: loss = 0.20 (0.007 sec)
# Step 756: loss = 0.22 (0.007 sec)
# Step 758: loss = 0.07 (0.007 sec)
# Step 760: loss = 6.62 (0.007 sec)
# Step 762: loss = 5.64 (0.007 sec)
# Step 764: loss = 3.47 (0.009 sec)
# Step 766: loss = 2.62 (0.008 sec)
# Step 768: loss = 2.10 (0.008 sec)
# Step 770: loss = 1.63 (0.008 sec)
# Step 772: loss = 1.72 (0.007 sec)
# Step 774: loss = 0.96 (0.007 sec)
# Step 776: loss = 0.76 (0.007 sec)
# Step 778: loss = 1.16 (0.007 sec)
# Step 780: loss = 3.40 (0.007 sec)
# Step 782: loss = 2.76 (0.007 sec)
# Step 784: loss = 2.52 (0.008 sec)
# Step 786: loss = 1.18 (0.008 sec)
# Step 788: loss = 1.00 (0.008 sec)
# Step 790: loss = 1.12 (0.007 sec)
# Step 792: loss = 0.77 (0.008 sec)
# Step 794: loss = 0.49 (0.007 sec)
# Step 796: loss = 0.47 (0.007 sec)
# Step 798: loss = 4.28 (0.007 sec)
# Step 800: loss = 4.46 (0.007 sec)
# Step 802: loss = 2.68 (0.007 sec)
# Step 804: loss = 1.95 (0.007 sec)
# Step 806: loss = 1.09 (0.007 sec)
# Step 808: loss = 0.82 (0.007 sec)
# Step 810: loss = 0.69 (0.007 sec)
# Step 812: loss = 0.77 (0.007 sec)
# Step 814: loss = 0.46 (0.007 sec)
# Step 816: loss = 0.23 (0.007 sec)
# Step 818: loss = 1.10 (0.007 sec)
# Step 820: loss = 1.73 (0.007 sec)
# Step 822: loss = 1.99 (0.007 sec)
# Step 824: loss = 1.38 (0.007 sec)
# Step 826: loss = 1.39 (0.007 sec)
# Step 828: loss = 1.35 (0.007 sec)
# Step 830: loss = 1.27 (0.007 sec)
# Step 832: loss = 1.05 (0.007 sec)
# Step 834: loss = 0.86 (0.007 sec)
# Step 836: loss = 0.80 (0.007 sec)
# Step 838: loss = 0.81 (0.007 sec)
# Step 840: loss = 0.55 (0.007 sec)
# Step 842: loss = 3.18 (0.007 sec)
# Step 844: loss = 3.50 (0.007 sec)
# Step 846: loss = 2.47 (0.007 sec)
# Step 848: loss = 2.12 (0.007 sec)
# Step 850: loss = 1.86 (0.007 sec)
# Step 852: loss = 1.38 (0.007 sec)
# Step 854: loss = 1.19 (0.007 sec)
# Step 856: loss = 0.71 (0.007 sec)
# Step 858: loss = 0.56 (0.007 sec)
# Step 860: loss = 0.50 (0.007 sec)
# Step 862: loss = 3.17 (0.007 sec)
# Step 864: loss = 3.02 (0.007 sec)
# Step 866: loss = 2.86 (0.008 sec)
# Step 868: loss = 2.08 (0.007 sec)
# Step 870: loss = 2.09 (0.007 sec)
# Step 872: loss = 1.67 (0.007 sec)
# Step 874: loss = 0.80 (0.007 sec)
# Step 876: loss = 0.53 (0.007 sec)
# Step 878: loss = 0.37 (0.007 sec)
# Step 880: loss = 0.27 (0.007 sec)
# Step 882: loss = 4.23 (0.007 sec)
# Step 884: loss = 2.94 (0.007 sec)
# Step 886: loss = 1.33 (0.007 sec)
# Step 888: loss = 1.40 (0.008 sec)
# Step 890: loss = 0.81 (0.007 sec)
# Step 892: loss = 0.62 (0.007 sec)
# Step 894: loss = 0.45 (0.007 sec)
# Step 896: loss = 0.15 (0.007 sec)
# Step 898: loss = 0.22 (0.007 sec)
# Step 900: loss = 0.19 (0.007 sec)
# Step 902: loss = 6.21 (0.007 sec)
# Step 904: loss = 4.26 (0.007 sec)
# Step 906: loss = 3.01 (0.007 sec)
# Step 908: loss = 2.57 (0.007 sec)
# Step 910: loss = 2.31 (0.007 sec)
# Step 912: loss = 1.73 (0.007 sec)
# Step 914: loss = 1.74 (0.007 sec)
# Step 916: loss = 1.62 (0.007 sec)
# Step 918: loss = 0.43 (0.007 sec)
# Step 920: loss = 3.71 (0.007 sec)
# Step 922: loss = 2.20 (0.007 sec)
# Step 924: loss = 1.67 (0.007 sec)
# Step 926: loss = 1.13 (0.007 sec)
# Step 928: loss = 0.55 (0.007 sec)
# Step 930: loss = 0.31 (0.007 sec)
# Step 932: loss = 0.28 (0.007 sec)
# Step 934: loss = 0.24 (0.007 sec)
# Step 936: loss = 0.06 (0.007 sec)
# Step 938: loss = 6.74 (0.007 sec)
# Step 940: loss = 12.37 (0.007 sec)
# Step 942: loss = 1.35 (0.007 sec)
# Step 944: loss = 0.22 (0.007 sec)
# Step 946: loss = 0.21 (0.007 sec)
# Step 948: loss = 0.29 (0.007 sec)
# Step 950: loss = 0.01 (0.007 sec)
# Step 952: loss = 0.18 (0.007 sec)
# Step 954: loss = 0.05 (0.008 sec)
# Step 956: loss = 0.04 (0.007 sec)
# Step 958: loss = 0.04 (0.007 sec)
# Step 960: loss = 4.72 (0.007 sec)
# Step 962: loss = 4.52 (0.007 sec)
# Step 964: loss = 3.46 (0.007 sec)
# Step 966: loss = 2.13 (0.007 sec)
# Step 968: loss = 1.70 (0.007 sec)
# Step 970: loss = 1.21 (0.007 sec)
# Step 972: loss = 1.28 (0.007 sec)
# Step 974: loss = 0.88 (0.008 sec)
# Step 976: loss = 0.49 (0.007 sec)
# Step 978: loss = 0.87 (0.007 sec)
# Step 980: loss = 3.62 (0.007 sec)
# Step 982: loss = 2.10 (0.007 sec)
# Step 984: loss = 2.08 (0.007 sec)
# Step 986: loss = 0.92 (0.007 sec)
# Step 988: loss = 1.10 (0.007 sec)
# Step 990: loss = 1.23 (0.007 sec)
# Step 992: loss = 1.16 (0.007 sec)
# Step 994: loss = 0.77 (0.007 sec)
# Step 996: loss = 0.56 (0.007 sec)
# Step 998: loss = 3.62 (0.007 sec)
# Training Data Eval:
#   Num examples: 10000  Num correct: 3321  Precision @1.00: 0.3321
# Step 1000: loss = 2.68 (0.007 sec)
# Step 1002: loss = 2.52 (0.007 sec)
# Step 1004: loss = 1.89 (0.007 sec)
# Step 1006: loss = 1.49 (0.007 sec)
# Step 1008: loss = 1.09 (0.007 sec)
# Step 1010: loss = 0.90 (0.007 sec)
# Step 1012: loss = 0.68 (0.007 sec)
# Step 1014: loss = 0.42 (0.008 sec)
# Step 1016: loss = 0.21 (0.007 sec)
# Step 1018: loss = 1.25 (0.007 sec)
# Step 1020: loss = 1.38 (0.007 sec)
# Step 1022: loss = 1.27 (0.007 sec)
# Step 1024: loss = 0.91 (0.007 sec)
# Step 1026: loss = 1.02 (0.007 sec)
# Step 1028: loss = 0.74 (0.007 sec)
# Step 1030: loss = 0.73 (0.008 sec)
# Step 1032: loss = 0.73 (0.007 sec)
# Step 1034: loss = 0.62 (0.007 sec)
# Step 1036: loss = 0.42 (0.007 sec)
# Step 1038: loss = 0.59 (0.007 sec)
# Step 1040: loss = 0.30 (0.007 sec)
# Step 1042: loss = 4.06 (0.007 sec)
# Step 1044: loss = 3.44 (0.007 sec)
# Step 1046: loss = 2.63 (0.007 sec)
# Step 1048: loss = 1.57 (0.007 sec)
# Step 1050: loss = 1.41 (0.007 sec)
# Step 1052: loss = 0.86 (0.007 sec)
# Step 1054: loss = 0.60 (0.007 sec)
# Step 1056: loss = 0.48 (0.007 sec)
# Step 1058: loss = 0.32 (0.008 sec)
# Step 1060: loss = 0.06 (0.007 sec)
# Step 1062: loss = 11.42 (0.007 sec)
# Step 1064: loss = 4.15 (0.007 sec)
# Step 1066: loss = 3.03 (0.008 sec)
# Step 1068: loss = 2.24 (0.007 sec)
# Step 1070: loss = 2.00 (0.007 sec)
# Step 1072: loss = 1.57 (0.007 sec)
# Step 1074: loss = 0.96 (0.007 sec)
# Step 1076: loss = 0.98 (0.007 sec)
# Step 1078: loss = 0.69 (0.007 sec)
# Step 1080: loss = 0.65 (0.007 sec)
# Step 1082: loss = 2.23 (0.007 sec)
# Step 1084: loss = 1.76 (0.007 sec)
# Step 1086: loss = 1.39 (0.007 sec)
# Step 1088: loss = 1.26 (0.007 sec)
# Step 1090: loss = 0.80 (0.007 sec)
# Step 1092: loss = 0.39 (0.008 sec)
# Step 1094: loss = 0.48 (0.008 sec)
# Step 1096: loss = 0.06 (0.007 sec)
# Step 1098: loss = 0.03 (0.007 sec)
# Step 1100: loss = 0.07 (0.007 sec)
# Step 1102: loss = 6.07 (0.007 sec)
# Step 1104: loss = 4.41 (0.007 sec)
# Step 1106: loss = 2.39 (0.007 sec)
# Step 1108: loss = 1.95 (0.007 sec)
# Step 1110: loss = 1.56 (0.007 sec)
# Step 1112: loss = 1.02 (0.007 sec)
# Step 1114: loss = 0.92 (0.007 sec)
# Step 1116: loss = 0.52 (0.007 sec)
# Step 1118: loss = 0.25 (0.007 sec)
# Step 1120: loss = 6.80 (0.007 sec)
# Step 1122: loss = 3.95 (0.007 sec)
# Step 1124: loss = 3.44 (0.007 sec)
# Step 1126: loss = 2.16 (0.007 sec)
# Step 1128: loss = 0.90 (0.007 sec)
# Step 1130: loss = 0.51 (0.007 sec)
# Step 1132: loss = 0.37 (0.007 sec)
# Step 1134: loss = 0.27 (0.007 sec)
# Step 1136: loss = 0.07 (0.007 sec)
# Step 1138: loss = 1.36 (0.007 sec)
# Step 1140: loss = 6.88 (0.007 sec)
# Step 1142: loss = 3.97 (0.007 sec)
# Step 1144: loss = 1.05 (0.008 sec)
# Step 1146: loss = 0.63 (0.007 sec)
# Step 1148: loss = 0.07 (0.007 sec)
# Step 1150: loss = 0.00 (0.007 sec)
# Step 1152: loss = 0.00 (0.008 sec)
# Step 1154: loss = 0.00 (0.007 sec)
# Step 1156: loss = 0.00 (0.007 sec)
# Step 1158: loss = 0.00 (0.007 sec)
# Step 1160: loss = 93.64 (0.007 sec)
# Step 1162: loss = 11.78 (0.007 sec)
# Step 1164: loss = 1.53 (0.007 sec)
# Step 1166: loss = 1.99 (0.007 sec)
# Step 1168: loss = 0.89 (0.007 sec)
# Step 1170: loss = 0.50 (0.007 sec)
# Step 1172: loss = 0.77 (0.007 sec)
# Step 1174: loss = 0.31 (0.008 sec)
# Step 1176: loss = 0.43 (0.007 sec)
# Step 1178: loss = 0.88 (0.007 sec)
# Step 1180: loss = 4.42 (0.007 sec)
# Step 1182: loss = 2.81 (0.007 sec)
# Step 1184: loss = 1.99 (0.007 sec)
# Step 1186: loss = 0.55 (0.007 sec)
# Step 1188: loss = 0.70 (0.007 sec)
# Step 1190: loss = 0.43 (0.007 sec)
# Step 1192: loss = 0.24 (0.007 sec)
# Step 1194: loss = 0.27 (0.007 sec)
# Step 1196: loss = 0.18 (0.007 sec)
# Step 1198: loss = 4.10 (0.007 sec)
# Step 1200: loss = 3.13 (0.007 sec)
# Step 1202: loss = 2.49 (0.007 sec)
# Step 1204: loss = 1.23 (0.007 sec)
# Step 1206: loss = 0.61 (0.007 sec)
# Step 1208: loss = 0.29 (0.007 sec)
# Step 1210: loss = 0.38 (0.007 sec)
# Step 1212: loss = 0.18 (0.007 sec)
# Step 1214: loss = 0.07 (0.007 sec)
# Step 1216: loss = 0.03 (0.007 sec)
# Step 1218: loss = 1.89 (0.007 sec)
# Step 1220: loss = 2.19 (0.007 sec)
# Step 1222: loss = 1.91 (0.007 sec)
# Step 1224: loss = 1.10 (0.007 sec)
# Step 1226: loss = 0.78 (0.007 sec)
# Step 1228: loss = 0.45 (0.007 sec)
# Step 1230: loss = 0.28 (0.007 sec)
# Step 1232: loss = 0.44 (0.007 sec)
# Step 1234: loss = 0.30 (0.007 sec)
# Step 1236: loss = 0.17 (0.007 sec)
# Step 1238: loss = 0.56 (0.007 sec)
# Step 1240: loss = 0.08 (0.007 sec)
# Step 1242: loss = 5.31 (0.007 sec)
# Step 1244: loss = 4.00 (0.007 sec)
# Step 1246: loss = 2.52 (0.007 sec)
# Step 1248: loss = 1.98 (0.007 sec)
# Step 1250: loss = 1.20 (0.007 sec)
# Step 1252: loss = 0.65 (0.007 sec)
# Step 1254: loss = 1.04 (0.007 sec)
# Step 1256: loss = 0.44 (0.007 sec)
# Step 1258: loss = 0.22 (0.007 sec)
# Step 1260: loss = 0.52 (0.007 sec)
# Step 1262: loss = 5.87 (0.007 sec)
# Step 1264: loss = 4.32 (0.007 sec)
# Step 1266: loss = 2.93 (0.007 sec)
# Step 1268: loss = 2.24 (0.007 sec)
# Step 1270: loss = 1.92 (0.007 sec)
# Step 1272: loss = 1.34 (0.007 sec)
# Step 1274: loss = 0.87 (0.007 sec)
# Step 1276: loss = 0.80 (0.007 sec)
# Step 1278: loss = 0.65 (0.007 sec)
# Step 1280: loss = 0.50 (0.007 sec)
# Step 1282: loss = 1.96 (0.007 sec)
# Step 1284: loss = 2.16 (0.008 sec)
# Step 1286: loss = 1.75 (0.007 sec)
# Step 1288: loss = 1.26 (0.007 sec)
# Step 1290: loss = 1.15 (0.007 sec)
# Step 1292: loss = 0.92 (0.007 sec)
# Step 1294: loss = 0.65 (0.007 sec)
# Step 1296: loss = 0.27 (0.007 sec)
# Step 1298: loss = 0.12 (0.007 sec)
# Step 1300: loss = 0.45 (0.007 sec)
# Step 1302: loss = 4.61 (0.009 sec)
# Step 1304: loss = 4.50 (0.009 sec)
# Step 1306: loss = 3.18 (0.007 sec)
# Step 1308: loss = 2.45 (0.007 sec)
# Step 1310: loss = 1.94 (0.007 sec)
# Step 1312: loss = 1.31 (0.007 sec)
# Step 1314: loss = 1.07 (0.007 sec)
# Step 1316: loss = 0.26 (0.007 sec)
# Step 1318: loss = 0.06 (0.007 sec)
# Step 1320: loss = 5.53 (0.007 sec)
# Step 1322: loss = 1.91 (0.007 sec)
# Step 1324: loss = 1.23 (0.007 sec)
# Step 1326: loss = 0.91 (0.007 sec)
# Step 1328: loss = 0.45 (0.008 sec)
# Step 1330: loss = 0.33 (0.008 sec)
# Step 1332: loss = 0.42 (0.007 sec)
# Step 1334: loss = 0.20 (0.007 sec)
# Step 1336: loss = 0.13 (0.007 sec)
# Step 1338: loss = 1.39 (0.007 sec)
# Step 1340: loss = 4.17 (0.007 sec)
# Step 1342: loss = 3.33 (0.007 sec)
# Step 1344: loss = 1.94 (0.007 sec)
# Step 1346: loss = 1.36 (0.007 sec)
# Step 1348: loss = 0.38 (0.007 sec)
# Step 1350: loss = 0.42 (0.008 sec)
# Step 1352: loss = 0.28 (0.007 sec)
# Step 1354: loss = 0.42 (0.007 sec)
# Step 1356: loss = 0.01 (0.008 sec)
# Step 1358: loss = 0.00 (0.007 sec)
# Step 1360: loss = 6.91 (0.007 sec)
# Step 1362: loss = 6.54 (0.007 sec)
# Step 1364: loss = 3.50 (0.008 sec)
# Step 1366: loss = 2.91 (0.007 sec)
# Step 1368: loss = 2.17 (0.008 sec)
# Step 1370: loss = 1.77 (0.007 sec)
# Step 1372: loss = 1.43 (0.007 sec)
# Step 1374: loss = 1.23 (0.007 sec)
# Step 1376: loss = 0.74 (0.008 sec)
# Step 1378: loss = 1.23 (0.007 sec)
# Step 1380: loss = 3.59 (0.007 sec)
# Step 1382: loss = 1.69 (0.007 sec)
# Step 1384: loss = 1.43 (0.007 sec)
# Step 1386: loss = 0.59 (0.007 sec)
# Step 1388: loss = 0.68 (0.007 sec)
# Step 1390: loss = 0.67 (0.007 sec)
# Step 1392: loss = 0.12 (0.007 sec)
# Step 1394: loss = 0.32 (0.007 sec)
# Step 1396: loss = 0.12 (0.007 sec)
# Step 1398: loss = 5.13 (0.007 sec)
# Step 1400: loss = 3.02 (0.009 sec)
# Step 1402: loss = 2.18 (0.007 sec)
# Step 1404: loss = 1.24 (0.007 sec)
# Step 1406: loss = 0.48 (0.007 sec)
# Step 1408: loss = 0.25 (0.007 sec)
# Step 1410: loss = 0.26 (0.008 sec)
# Step 1412: loss = 0.11 (0.008 sec)
# Step 1414: loss = 0.07 (0.008 sec)
# Step 1416: loss = 0.04 (0.007 sec)
# Step 1418: loss = 0.85 (0.007 sec)
# Step 1420: loss = 1.40 (0.009 sec)
# Step 1422: loss = 1.03 (0.007 sec)
# Step 1424: loss = 0.33 (0.007 sec)
# Step 1426: loss = 0.49 (0.007 sec)
# Step 1428: loss = 0.20 (0.007 sec)
# Step 1430: loss = 0.23 (0.007 sec)
# Step 1432: loss = 0.51 (0.007 sec)
# Step 1434: loss = 0.08 (0.007 sec)
# Step 1436: loss = 0.06 (0.007 sec)
# Step 1438: loss = 0.40 (0.007 sec)
# Step 1440: loss = 0.12 (0.007 sec)
# Step 1442: loss = 4.26 (0.007 sec)
# Step 1444: loss = 4.46 (0.007 sec)
# Step 1446: loss = 3.09 (0.007 sec)
# Step 1448: loss = 1.85 (0.007 sec)
# Step 1450: loss = 1.52 (0.008 sec)
# Step 1452: loss = 1.46 (0.007 sec)
# Step 1454: loss = 0.94 (0.007 sec)
# Step 1456: loss = 0.53 (0.007 sec)
# Step 1458: loss = 0.35 (0.007 sec)
# Step 1460: loss = 0.34 (0.007 sec)
# Step 1462: loss = 3.79 (0.007 sec)
# Step 1464: loss = 3.14 (0.007 sec)
# Step 1466: loss = 2.86 (0.007 sec)
# Step 1468: loss = 1.64 (0.007 sec)
# Step 1470: loss = 1.67 (0.007 sec)
# Step 1472: loss = 1.30 (0.007 sec)
# Step 1474: loss = 0.97 (0.007 sec)
# Step 1476: loss = 0.76 (0.007 sec)
# Step 1478: loss = 0.71 (0.007 sec)
# Step 1480: loss = 0.58 (0.008 sec)
# Step 1482: loss = 1.33 (0.007 sec)
# Step 1484: loss = 1.96 (0.007 sec)
# Step 1486: loss = 1.40 (0.007 sec)
# Step 1488: loss = 1.19 (0.007 sec)
# Step 1490: loss = 0.99 (0.007 sec)
# Step 1492: loss = 0.60 (0.007 sec)
# Step 1494: loss = 0.51 (0.007 sec)
# Step 1496: loss = 0.23 (0.007 sec)
# Step 1498: loss = 0.07 (0.007 sec)
# Step 1500: loss = 0.11 (0.007 sec)
# Step 1502: loss = 4.40 (0.007 sec)
# Step 1504: loss = 3.94 (0.007 sec)
# Step 1506: loss = 2.60 (0.007 sec)
# Step 1508: loss = 1.72 (0.007 sec)
# Step 1510: loss = 1.22 (0.007 sec)
# Step 1512: loss = 0.93 (0.007 sec)
# Step 1514: loss = 0.55 (0.008 sec)
# Step 1516: loss = 0.34 (0.007 sec)
# Step 1518: loss = 0.00 (0.007 sec)
# Step 1520: loss = 8.73 (0.007 sec)
# Step 1522: loss = 2.97 (0.008 sec)
# Step 1524: loss = 1.41 (0.007 sec)
# Step 1526: loss = 1.04 (0.007 sec)
# Step 1528: loss = 0.43 (0.007 sec)
# Step 1530: loss = 0.04 (0.007 sec)
# Step 1532: loss = 0.37 (0.007 sec)
# Step 1534: loss = 0.13 (0.007 sec)
# Step 1536: loss = 0.03 (0.007 sec)
# Step 1538: loss = 1.35 (0.007 sec)
# Step 1540: loss = 5.07 (0.007 sec)
# Step 1542: loss = 2.60 (0.007 sec)
# Step 1544: loss = 0.73 (0.007 sec)
# Step 1546: loss = 0.68 (0.007 sec)
# Step 1548: loss = 0.04 (0.007 sec)
# Step 1550: loss = 0.32 (0.007 sec)
# Step 1552: loss = 0.02 (0.007 sec)
# Step 1554: loss = 0.22 (0.007 sec)
# Step 1556: loss = 0.00 (0.008 sec)
# Step 1558: loss = 0.11 (0.007 sec)
# Step 1560: loss = 31.35 (0.007 sec)
# Step 1562: loss = 5.43 (0.007 sec)
# Step 1564: loss = 1.15 (0.007 sec)
# Step 1566: loss = 1.71 (0.007 sec)
# Step 1568: loss = 0.92 (0.007 sec)
# Step 1570: loss = 0.56 (0.008 sec)
# Step 1572: loss = 0.32 (0.007 sec)
# Step 1574: loss = 0.13 (0.007 sec)
# Step 1576: loss = 0.10 (0.007 sec)
# Step 1578: loss = 3.06 (0.007 sec)
# Step 1580: loss = 8.82 (0.007 sec)
# Step 1582: loss = 1.36 (0.007 sec)
# Step 1584: loss = 1.11 (0.007 sec)
# Step 1586: loss = 0.96 (0.007 sec)
# Step 1588: loss = 1.03 (0.007 sec)
# Step 1590: loss = 0.69 (0.007 sec)
# Step 1592: loss = 0.61 (0.007 sec)
# Step 1594: loss = 0.57 (0.007 sec)
# Step 1596: loss = 0.28 (0.008 sec)
# Step 1598: loss = 2.45 (0.007 sec)
# Step 1600: loss = 1.82 (0.007 sec)
# Step 1602: loss = 1.37 (0.007 sec)
# Step 1604: loss = 0.96 (0.007 sec)
# Step 1606: loss = 0.44 (0.007 sec)
# Step 1608: loss = 0.29 (0.007 sec)
# Step 1610: loss = 0.34 (0.007 sec)
# Step 1612: loss = 0.21 (0.008 sec)
# Step 1614: loss = 0.07 (0.007 sec)
# Step 1616: loss = 0.01 (0.008 sec)
# Step 1618: loss = 1.83 (0.007 sec)
# Step 1620: loss = 1.60 (0.007 sec)
# Step 1622: loss = 1.71 (0.007 sec)
# Step 1624: loss = 1.12 (0.007 sec)
# Step 1626: loss = 0.80 (0.007 sec)
# Step 1628: loss = 0.48 (0.007 sec)
# Step 1630: loss = 0.33 (0.007 sec)
# Step 1632: loss = 0.21 (0.007 sec)
# Step 1634: loss = 0.27 (0.007 sec)
# Step 1636: loss = 0.08 (0.007 sec)
# Step 1638: loss = 0.30 (0.007 sec)
# Step 1640: loss = 0.08 (0.007 sec)
# Step 1642: loss = 3.53 (0.007 sec)
# Step 1644: loss = 3.32 (0.007 sec)
# Step 1646: loss = 1.82 (0.008 sec)
# Step 1648: loss = 1.04 (0.008 sec)
# Step 1650: loss = 0.84 (0.008 sec)
# Step 1652: loss = 0.55 (0.007 sec)
# Step 1654: loss = 0.42 (0.007 sec)
# Step 1656: loss = 0.14 (0.007 sec)
# Step 1658: loss = 0.12 (0.007 sec)
# Step 1660: loss = 0.11 (0.007 sec)
# Step 1662: loss = 11.58 (0.007 sec)
# Step 1664: loss = 5.46 (0.007 sec)
# Step 1666: loss = 2.47 (0.007 sec)
# Step 1668: loss = 1.46 (0.008 sec)
# Step 1670: loss = 1.18 (0.008 sec)
# Step 1672: loss = 0.92 (0.007 sec)
# Step 1674: loss = 0.46 (0.007 sec)
# Step 1676: loss = 0.35 (0.007 sec)
# Step 1678: loss = 0.29 (0.007 sec)
# Step 1680: loss = 0.29 (0.007 sec)
# Step 1682: loss = 1.68 (0.007 sec)
# Step 1684: loss = 1.43 (0.007 sec)
# Step 1686: loss = 1.01 (0.007 sec)
# Step 1688: loss = 0.76 (0.007 sec)
# Step 1690: loss = 0.56 (0.008 sec)
# Step 1692: loss = 0.19 (0.007 sec)
# Step 1694: loss = 0.33 (0.007 sec)
# Step 1696: loss = 0.17 (0.007 sec)
# Step 1698: loss = 0.02 (0.007 sec)
# Step 1700: loss = 0.07 (0.007 sec)
# Step 1702: loss = 8.56 (0.007 sec)
# Step 1704: loss = 4.80 (0.007 sec)
# Step 1706: loss = 1.91 (0.007 sec)
# Step 1708: loss = 1.14 (0.007 sec)
# Step 1710: loss = 0.55 (0.007 sec)
# Step 1712: loss = 0.57 (0.007 sec)
# Step 1714: loss = 0.45 (0.007 sec)
# Step 1716: loss = 0.02 (0.008 sec)
# Step 1718: loss = 0.00 (0.008 sec)
# Step 1720: loss = 4.22 (0.007 sec)
# Step 1722: loss = 2.37 (0.007 sec)
# Step 1724: loss = 1.42 (0.007 sec)
# Step 1726: loss = 0.88 (0.007 sec)
# Step 1728: loss = 0.26 (0.007 sec)
# Step 1730: loss = 0.16 (0.007 sec)
# Step 1732: loss = 0.22 (0.008 sec)
# Step 1734: loss = 0.14 (0.007 sec)
# Step 1736: loss = 0.03 (0.007 sec)
# Step 1738: loss = 3.99 (0.007 sec)
# Step 1740: loss = 5.07 (0.007 sec)
# Step 1742: loss = 1.46 (0.007 sec)
# Step 1744: loss = 0.75 (0.007 sec)
# Step 1746: loss = 1.10 (0.007 sec)
# Step 1748: loss = 0.22 (0.007 sec)
# Step 1750: loss = 0.14 (0.007 sec)
# Step 1752: loss = 0.24 (0.007 sec)
# Step 1754: loss = 0.12 (0.007 sec)
# Step 1756: loss = 0.00 (0.007 sec)
# Step 1758: loss = 0.00 (0.007 sec)
# Step 1760: loss = 8.92 (0.007 sec)
# Step 1762: loss = 3.52 (0.007 sec)
# Step 1764: loss = 1.73 (0.007 sec)
# Step 1766: loss = 1.49 (0.007 sec)
# Step 1768: loss = 0.47 (0.007 sec)
# Step 1770: loss = 0.30 (0.007 sec)
# Step 1772: loss = 0.18 (0.007 sec)
# Step 1774: loss = 0.05 (0.007 sec)
# Step 1776: loss = 0.04 (0.007 sec)
# Step 1778: loss = 1.03 (0.007 sec)
# Step 1780: loss = 4.05 (0.008 sec)
# Step 1782: loss = 1.67 (0.007 sec)
# Step 1784: loss = 1.22 (0.007 sec)
# Step 1786: loss = 0.50 (0.007 sec)
# Step 1788: loss = 0.48 (0.008 sec)
# Step 1790: loss = 0.55 (0.007 sec)
# Step 1792: loss = 0.39 (0.008 sec)
# Step 1794: loss = 0.28 (0.008 sec)
# Step 1796: loss = 0.12 (0.008 sec)
# Step 1798: loss = 3.22 (0.009 sec)
# Step 1800: loss = 2.18 (0.008 sec)
# Step 1802: loss = 1.71 (0.007 sec)
# Step 1804: loss = 1.19 (0.007 sec)
# Step 1806: loss = 0.91 (0.007 sec)
# Step 1808: loss = 0.47 (0.008 sec)
# Step 1810: loss = 0.27 (0.007 sec)
# Step 1812: loss = 0.13 (0.007 sec)
# Step 1814: loss = 0.08 (0.007 sec)
# Step 1816: loss = 0.00 (0.007 sec)
# Step 1818: loss = 2.07 (0.007 sec)
# Step 1820: loss = 1.39 (0.007 sec)
# Step 1822: loss = 0.84 (0.007 sec)
# Step 1824: loss = 0.13 (0.007 sec)
# Step 1826: loss = 0.21 (0.007 sec)
# Step 1828: loss = 0.07 (0.007 sec)
# Step 1830: loss = 0.02 (0.007 sec)
# Step 1832: loss = 0.35 (0.007 sec)
# Step 1834: loss = 0.02 (0.008 sec)
# Step 1836: loss = 0.01 (0.008 sec)
# Step 1838: loss = 0.56 (0.007 sec)
# Step 1840: loss = 0.00 (0.007 sec)
# Step 1842: loss = 9.77 (0.007 sec)
# Step 1844: loss = 4.86 (0.008 sec)
# Step 1846: loss = 1.98 (0.007 sec)
# Step 1848: loss = 1.06 (0.007 sec)
# Step 1850: loss = 0.49 (0.007 sec)
# Step 1852: loss = 0.65 (0.008 sec)
# Step 1854: loss = 0.48 (0.007 sec)
# Step 1856: loss = 0.16 (0.007 sec)
# Step 1858: loss = 0.12 (0.007 sec)
# Step 1860: loss = 0.13 (0.007 sec)
# Step 1862: loss = 2.95 (0.007 sec)
# Step 1864: loss = 2.72 (0.007 sec)
# Step 1866: loss = 2.41 (0.007 sec)
# Step 1868: loss = 1.12 (0.007 sec)
# Step 1870: loss = 1.35 (0.007 sec)
# Step 1872: loss = 0.71 (0.007 sec)
# Step 1874: loss = 0.58 (0.007 sec)
# Step 1876: loss = 0.41 (0.007 sec)
# Step 1878: loss = 0.27 (0.007 sec)
# Step 1880: loss = 0.30 (0.007 sec)
# Step 1882: loss = 2.00 (0.007 sec)
# Step 1884: loss = 1.44 (0.007 sec)
# Step 1886: loss = 1.51 (0.007 sec)
# Step 1888: loss = 1.17 (0.007 sec)
# Step 1890: loss = 0.75 (0.007 sec)
# Step 1892: loss = 0.27 (0.007 sec)
# Step 1894: loss = 0.31 (0.007 sec)
# Step 1896: loss = 0.07 (0.008 sec)
# Step 1898: loss = 0.04 (0.007 sec)
# Step 1900: loss = 0.05 (0.007 sec)
# Step 1902: loss = 4.20 (0.007 sec)
# Step 1904: loss = 3.67 (0.007 sec)
# Step 1906: loss = 1.81 (0.007 sec)
# Step 1908: loss = 1.42 (0.007 sec)
# Step 1910: loss = 1.21 (0.007 sec)
# Step 1912: loss = 0.81 (0.007 sec)
# Step 1914: loss = 0.60 (0.007 sec)
# Step 1916: loss = 0.40 (0.007 sec)
# Step 1918: loss = 0.43 (0.007 sec)
# Step 1920: loss = 2.42 (0.007 sec)
# Step 1922: loss = 2.26 (0.007 sec)
# Step 1924: loss = 1.38 (0.007 sec)
# Step 1926: loss = 1.25 (0.008 sec)
# Step 1928: loss = 0.48 (0.007 sec)
# Step 1930: loss = 0.24 (0.007 sec)
# Step 1932: loss = 0.40 (0.007 sec)
# Step 1934: loss = 0.04 (0.007 sec)
# Step 1936: loss = 0.00 (0.007 sec)
# Step 1938: loss = 1.94 (0.007 sec)
# Step 1940: loss = 7.01 (0.007 sec)
# Step 1942: loss = 3.10 (0.007 sec)
# Step 1944: loss = 1.08 (0.007 sec)
# Step 1946: loss = 0.84 (0.007 sec)
# Step 1948: loss = 0.24 (0.007 sec)
# Step 1950: loss = 0.11 (0.008 sec)
# Step 1952: loss = 0.44 (0.007 sec)
# Step 1954: loss = 0.03 (0.008 sec)
# Step 1956: loss = 0.06 (0.008 sec)
# Step 1958: loss = 0.08 (0.007 sec)
# Step 1960: loss = 5.58 (0.007 sec)
# Step 1962: loss = 3.46 (0.007 sec)
# Step 1964: loss = 3.09 (0.008 sec)
# Step 1966: loss = 2.67 (0.007 sec)
# Step 1968: loss = 1.57 (0.007 sec)
# Step 1970: loss = 1.08 (0.007 sec)
# Step 1972: loss = 0.83 (0.007 sec)
# Step 1974: loss = 0.39 (0.007 sec)
# Step 1976: loss = 0.47 (0.007 sec)
# Step 1978: loss = 0.67 (0.007 sec)
# Step 1980: loss = 2.70 (0.007 sec)
# Step 1982: loss = 1.19 (0.008 sec)
# Step 1984: loss = 1.15 (0.007 sec)
# Step 1986: loss = 0.57 (0.007 sec)
# Step 1988: loss = 0.93 (0.007 sec)
# Step 1990: loss = 0.77 (0.007 sec)
# Step 1992: loss = 0.47 (0.007 sec)
# Step 1994: loss = 0.29 (0.007 sec)
# Step 1996: loss = 0.32 (0.007 sec)
# Step 1998: loss = 8.03 (0.007 sec)
# Training Data Eval:
#   Num examples: 10000  Num correct: 3520  Precision @1.00: 0.3520
# Step 2000: loss = 3.37 (0.007 sec)
# Step 2002: loss = 1.91 (0.007 sec)
# Step 2004: loss = 1.42 (0.007 sec)
# Step 2006: loss = 0.90 (0.007 sec)
# Step 2008: loss = 0.53 (0.007 sec)
# Step 2010: loss = 0.42 (0.007 sec)
# Step 2012: loss = 0.25 (0.007 sec)
# Step 2014: loss = 0.07 (0.007 sec)
# Step 2016: loss = 0.07 (0.007 sec)
# Step 2018: loss = 0.99 (0.007 sec)
# Step 2020: loss = 1.16 (0.007 sec)
# Step 2022: loss = 1.04 (0.007 sec)
# Step 2024: loss = 0.53 (0.007 sec)
# Step 2026: loss = 0.85 (0.007 sec)
# Step 2028: loss = 0.40 (0.007 sec)
# Step 2030: loss = 0.25 (0.007 sec)
# Step 2032: loss = 0.25 (0.007 sec)
# Step 2034: loss = 0.23 (0.007 sec)
# Step 2036: loss = 0.04 (0.007 sec)
# Step 2038: loss = 0.21 (0.008 sec)
# Step 2040: loss = 0.01 (0.007 sec)
# Step 2042: loss = 11.16 (0.007 sec)
# Step 2044: loss = 3.61 (0.007 sec)
# Step 2046: loss = 2.12 (0.007 sec)
# Step 2048: loss = 1.21 (0.008 sec)
# Step 2050: loss = 0.44 (0.007 sec)
# Step 2052: loss = 0.36 (0.007 sec)
# Step 2054: loss = 0.31 (0.007 sec)
# Step 2056: loss = 0.09 (0.007 sec)
# Step 2058: loss = 0.14 (0.008 sec)
# Step 2060: loss = 0.25 (0.007 sec)
# Step 2062: loss = 4.28 (0.007 sec)
# Step 2064: loss = 3.79 (0.008 sec)
# Step 2066: loss = 2.57 (0.007 sec)
# Step 2068: loss = 1.29 (0.007 sec)
# Step 2070: loss = 1.02 (0.007 sec)
# Step 2072: loss = 0.75 (0.007 sec)
# Step 2074: loss = 0.35 (0.007 sec)
# Step 2076: loss = 0.18 (0.007 sec)
# Step 2078: loss = 0.17 (0.007 sec)
# Step 2080: loss = 0.21 (0.008 sec)
# Step 2082: loss = 2.41 (0.007 sec)
# Step 2084: loss = 1.83 (0.007 sec)
# Step 2086: loss = 1.49 (0.007 sec)
# Step 2088: loss = 0.83 (0.007 sec)
# Step 2090: loss = 0.74 (0.007 sec)
# Step 2092: loss = 0.40 (0.007 sec)
# Step 2094: loss = 0.36 (0.007 sec)
# Step 2096: loss = 0.09 (0.007 sec)
# Step 2098: loss = 0.16 (0.007 sec)
# Step 2100: loss = 0.07 (0.007 sec)
# Step 2102: loss = 5.39 (0.007 sec)
# Step 2104: loss = 4.49 (0.007 sec)
# Step 2106: loss = 1.89 (0.007 sec)
# Step 2108: loss = 0.74 (0.007 sec)
# Step 2110: loss = 0.43 (0.007 sec)
# Step 2112: loss = 0.63 (0.007 sec)
# Step 2114: loss = 0.39 (0.007 sec)
# Step 2116: loss = 0.26 (0.007 sec)
# Step 2118: loss = 0.43 (0.007 sec)
# Step 2120: loss = 2.68 (0.007 sec)
# Step 2122: loss = 2.37 (0.008 sec)
# Step 2124: loss = 1.84 (0.008 sec)
# Step 2126: loss = 1.32 (0.007 sec)
# Step 2128: loss = 0.41 (0.007 sec)
# Step 2130: loss = 0.09 (0.008 sec)
# Step 2132: loss = 0.28 (0.007 sec)
# Step 2134: loss = 0.00 (0.007 sec)
# Step 2136: loss = 0.00 (0.007 sec)
# Step 2138: loss = 2.10 (0.007 sec)
# Step 2140: loss = 5.21 (0.007 sec)
# Step 2142: loss = 2.46 (0.007 sec)
# Step 2144: loss = 0.95 (0.007 sec)
# Step 2146: loss = 0.69 (0.007 sec)
# Step 2148: loss = 0.33 (0.007 sec)
# Step 2150: loss = 0.18 (0.007 sec)
# Step 2152: loss = 0.18 (0.008 sec)
# Step 2154: loss = 0.02 (0.007 sec)
# Step 2156: loss = 0.13 (0.007 sec)
# Step 2158: loss = 0.19 (0.007 sec)
# Step 2160: loss = 4.21 (0.007 sec)
# Step 2162: loss = 3.18 (0.007 sec)
# Step 2164: loss = 2.66 (0.007 sec)
# Step 2166: loss = 2.28 (0.007 sec)
# Step 2168: loss = 1.38 (0.008 sec)
# Step 2170: loss = 1.03 (0.007 sec)
# Step 2172: loss = 1.02 (0.007 sec)
# Step 2174: loss = 0.55 (0.007 sec)
# Step 2176: loss = 0.56 (0.007 sec)
# Step 2178: loss = 0.95 (0.007 sec)
# Step 2180: loss = 3.50 (0.007 sec)
# Step 2182: loss = 2.11 (0.008 sec)
# Step 2184: loss = 1.03 (0.007 sec)
# Step 2186: loss = 0.76 (0.007 sec)
# Step 2188: loss = 0.58 (0.007 sec)
# Step 2190: loss = 0.46 (0.007 sec)
# Step 2192: loss = 0.47 (0.007 sec)
# Step 2194: loss = 0.27 (0.007 sec)
# Step 2196: loss = 0.25 (0.007 sec)
# Step 2198: loss = 1.51 (0.007 sec)
# Step 2200: loss = 1.65 (0.007 sec)
# Step 2202: loss = 1.37 (0.007 sec)
# Step 2204: loss = 0.93 (0.007 sec)
# Step 2206: loss = 0.67 (0.007 sec)
# Step 2208: loss = 0.44 (0.007 sec)
# Step 2210: loss = 0.30 (0.007 sec)
# Step 2212: loss = 0.10 (0.007 sec)
# Step 2214: loss = 0.07 (0.007 sec)
# Step 2216: loss = 0.04 (0.007 sec)
# Step 2218: loss = 0.98 (0.007 sec)
# Step 2220: loss = 1.14 (0.007 sec)
# Step 2222: loss = 0.88 (0.008 sec)
# Step 2224: loss = 0.13 (0.008 sec)
# Step 2226: loss = 0.25 (0.007 sec)
# Step 2228: loss = 0.01 (0.007 sec)
# Step 2230: loss = 0.01 (0.008 sec)
# Step 2232: loss = 0.32 (0.007 sec)
# Step 2234: loss = 0.06 (0.007 sec)
# Step 2236: loss = 0.00 (0.007 sec)
# Step 2238: loss = 0.00 (0.007 sec)
# Step 2240: loss = 0.08 (0.007 sec)
# Step 2242: loss = 7.22 (0.007 sec)
# Step 2244: loss = 3.20 (0.007 sec)
# Step 2246: loss = 1.28 (0.007 sec)
# Step 2248: loss = 0.69 (0.007 sec)
# Step 2250: loss = 0.48 (0.007 sec)
# Step 2252: loss = 0.09 (0.007 sec)
# Step 2254: loss = 0.26 (0.007 sec)
# Step 2256: loss = 0.00 (0.007 sec)
# Step 2258: loss = 0.06 (0.007 sec)
# Step 2260: loss = 0.07 (0.007 sec)
# Step 2262: loss = 14.17 (0.007 sec)
# Step 2264: loss = 5.40 (0.008 sec)
# Step 2266: loss = 1.50 (0.008 sec)
# Step 2268: loss = 1.17 (0.007 sec)
# Step 2270: loss = 0.90 (0.007 sec)
# Step 2272: loss = 0.50 (0.008 sec)
# Step 2274: loss = 0.36 (0.007 sec)
# Step 2276: loss = 0.31 (0.007 sec)
# Step 2278: loss = 0.23 (0.007 sec)
# Step 2280: loss = 0.23 (0.007 sec)
# Step 2282: loss = 3.76 (0.007 sec)
# Step 2284: loss = 2.63 (0.007 sec)
# Step 2286: loss = 1.92 (0.007 sec)
# Step 2288: loss = 0.70 (0.007 sec)
# Step 2290: loss = 0.64 (0.007 sec)
# Step 2292: loss = 0.30 (0.007 sec)
# Step 2294: loss = 0.28 (0.007 sec)
# Step 2296: loss = 0.20 (0.007 sec)
# Step 2298: loss = 0.09 (0.007 sec)
# Step 2300: loss = 0.15 (0.007 sec)
# Step 2302: loss = 5.01 (0.007 sec)
# Step 2304: loss = 3.31 (0.007 sec)
# Step 2306: loss = 1.58 (0.007 sec)
# Step 2308: loss = 1.04 (0.008 sec)
# Step 2310: loss = 0.59 (0.007 sec)
# Step 2312: loss = 1.01 (0.007 sec)
# Step 2314: loss = 0.62 (0.007 sec)
# Step 2316: loss = 0.05 (0.007 sec)
# Step 2318: loss = 0.26 (0.007 sec)
# Step 2320: loss = 3.67 (0.007 sec)
# Step 2322: loss = 1.54 (0.007 sec)
# Step 2324: loss = 0.62 (0.007 sec)
# Step 2326: loss = 0.72 (0.007 sec)
# Step 2328: loss = 0.18 (0.007 sec)
# Step 2330: loss = 0.17 (0.007 sec)
# Step 2332: loss = 0.38 (0.008 sec)
# Step 2334: loss = 0.04 (0.007 sec)
# Step 2336: loss = 0.01 (0.007 sec)
# Step 2338: loss = 1.44 (0.007 sec)
# Step 2340: loss = 4.12 (0.007 sec)
# Step 2342: loss = 2.88 (0.007 sec)
# Step 2344: loss = 1.41 (0.007 sec)
# Step 2346: loss = 0.84 (0.007 sec)
# Step 2348: loss = 0.20 (0.007 sec)
# Step 2350: loss = 0.13 (0.007 sec)
# Step 2352: loss = 0.03 (0.007 sec)
# Step 2354: loss = 0.13 (0.007 sec)
# Step 2356: loss = 0.04 (0.007 sec)
# Step 2358: loss = 0.00 (0.007 sec)
# Step 2360: loss = 9.46 (0.007 sec)
# Step 2362: loss = 4.60 (0.008 sec)
# Step 2364: loss = 0.98 (0.007 sec)
# Step 2366: loss = 1.25 (0.007 sec)
# Step 2368: loss = 0.65 (0.007 sec)
# Step 2370: loss = 0.36 (0.007 sec)
# Step 2372: loss = 0.52 (0.007 sec)
# Step 2374: loss = 0.45 (0.007 sec)
# Step 2376: loss = 0.23 (0.007 sec)
# Step 2378: loss = 0.56 (0.007 sec)
# Step 2380: loss = 3.00 (0.007 sec)
# Step 2382: loss = 1.84 (0.007 sec)
# Step 2384: loss = 1.32 (0.007 sec)
# Step 2386: loss = 0.73 (0.007 sec)
# Step 2388: loss = 0.53 (0.007 sec)
# Step 2390: loss = 0.36 (0.007 sec)
# Step 2392: loss = 0.27 (0.007 sec)
# Step 2394: loss = 0.15 (0.008 sec)
# Step 2396: loss = 0.04 (0.007 sec)
# Step 2398: loss = 1.17 (0.007 sec)
# Step 2400: loss = 1.08 (0.007 sec)
# Step 2402: loss = 1.13 (0.007 sec)
# Step 2404: loss = 0.67 (0.007 sec)
# Step 2406: loss = 0.29 (0.007 sec)
# Step 2408: loss = 0.18 (0.007 sec)
# Step 2410: loss = 0.32 (0.007 sec)
# Step 2412: loss = 0.10 (0.007 sec)
# Step 2414: loss = 0.11 (0.007 sec)
# Step 2416: loss = 0.06 (0.007 sec)
# Step 2418: loss = 1.32 (0.008 sec)
# Step 2420: loss = 1.20 (0.007 sec)
# Step 2422: loss = 0.83 (0.007 sec)
# Step 2424: loss = 0.50 (0.007 sec)
# Step 2426: loss = 0.32 (0.007 sec)
# Step 2428: loss = 0.17 (0.007 sec)
# Step 2430: loss = 0.12 (0.007 sec)
# Step 2432: loss = 0.26 (0.007 sec)
# Step 2434: loss = 0.05 (0.007 sec)
# Step 2436: loss = 0.04 (0.007 sec)
# Step 2438: loss = 0.13 (0.007 sec)
# Step 2440: loss = 0.05 (0.007 sec)
# Step 2442: loss = 5.35 (0.007 sec)
# Step 2444: loss = 3.79 (0.007 sec)
# Step 2446: loss = 1.49 (0.007 sec)
# Step 2448: loss = 0.83 (0.007 sec)
# Step 2450: loss = 0.89 (0.007 sec)
# Step 2452: loss = 0.36 (0.008 sec)
# Step 2454: loss = 0.32 (0.007 sec)
# Step 2456: loss = 0.26 (0.007 sec)
# Step 2458: loss = 0.09 (0.007 sec)
# Step 2460: loss = 0.04 (0.007 sec)
# Step 2462: loss = 4.40 (0.007 sec)
# Step 2464: loss = 2.59 (0.007 sec)
# Step 2466: loss = 1.71 (0.007 sec)
# Step 2468: loss = 1.33 (0.007 sec)
# Step 2470: loss = 1.40 (0.007 sec)
# Step 2472: loss = 0.69 (0.008 sec)
# Step 2474: loss = 0.64 (0.007 sec)
# Step 2476: loss = 0.40 (0.007 sec)
# Step 2478: loss = 0.30 (0.007 sec)
# Step 2480: loss = 0.53 (0.007 sec)
# Step 2482: loss = 0.89 (0.008 sec)
# Step 2484: loss = 1.06 (0.007 sec)
# Step 2486: loss = 0.83 (0.007 sec)
# Step 2488: loss = 0.84 (0.007 sec)
# Step 2490: loss = 0.70 (0.007 sec)
# Step 2492: loss = 0.43 (0.007 sec)
# Step 2494: loss = 0.12 (0.007 sec)
# Step 2496: loss = 0.04 (0.007 sec)
# Step 2498: loss = 0.07 (0.007 sec)
# Step 2500: loss = 0.09 (0.007 sec)
# Step 2502: loss = 4.72 (0.007 sec)
# Step 2504: loss = 3.72 (0.007 sec)
# Step 2506: loss = 2.34 (0.007 sec)
# Step 2508: loss = 0.90 (0.007 sec)
# Step 2510: loss = 0.80 (0.007 sec)
# Step 2512: loss = 0.68 (0.007 sec)
# Step 2514: loss = 0.68 (0.007 sec)
# Step 2516: loss = 0.20 (0.007 sec)
# Step 2518: loss = 0.00 (0.007 sec)
# Step 2520: loss = 4.71 (0.007 sec)
# Step 2522: loss = 1.78 (0.007 sec)
# Step 2524: loss = 0.82 (0.007 sec)
# Step 2526: loss = 0.75 (0.007 sec)
# Step 2528: loss = 0.14 (0.007 sec)
# Step 2530: loss = 0.07 (0.007 sec)
# Step 2532: loss = 0.22 (0.007 sec)
# Step 2534: loss = 0.04 (0.007 sec)
# Step 2536: loss = 0.01 (0.007 sec)
# Step 2538: loss = 1.06 (0.007 sec)
# Step 2540: loss = 4.02 (0.007 sec)
# Step 2542: loss = 3.30 (0.007 sec)
# Step 2544: loss = 2.18 (0.007 sec)
# Step 2546: loss = 0.98 (0.008 sec)
# Step 2548: loss = 0.09 (0.007 sec)
# Step 2550: loss = 0.01 (0.007 sec)
# Step 2552: loss = 0.08 (0.007 sec)
# Step 2554: loss = 0.00 (0.007 sec)
# Step 2556: loss = 0.00 (0.007 sec)
# Step 2558: loss = 0.02 (0.007 sec)
# Step 2560: loss = 9.22 (0.007 sec)
# Step 2562: loss = 2.39 (0.007 sec)
# Step 2564: loss = 0.43 (0.007 sec)
# Step 2566: loss = 0.40 (0.007 sec)
# Step 2568: loss = 0.29 (0.007 sec)
# Step 2570: loss = 0.29 (0.007 sec)
# Step 2572: loss = 0.42 (0.007 sec)
# Step 2574: loss = 0.08 (0.007 sec)
# Step 2576: loss = 0.15 (0.007 sec)
# Step 2578: loss = 1.30 (0.007 sec)
# Step 2580: loss = 3.81 (0.007 sec)
# Step 2582: loss = 1.00 (0.007 sec)
# Step 2584: loss = 1.09 (0.007 sec)
# Step 2586: loss = 0.55 (0.007 sec)
# Step 2588: loss = 0.53 (0.007 sec)
# Step 2590: loss = 0.36 (0.007 sec)
# Step 2592: loss = 0.29 (0.007 sec)
# Step 2594: loss = 0.19 (0.007 sec)
# Step 2596: loss = 0.10 (0.007 sec)
# Step 2598: loss = 4.05 (0.007 sec)
# Step 2600: loss = 2.72 (0.007 sec)
# Step 2602: loss = 2.15 (0.007 sec)
# Step 2604: loss = 1.53 (0.007 sec)
# Step 2606: loss = 0.72 (0.007 sec)
# Step 2608: loss = 0.75 (0.007 sec)
# Step 2610: loss = 0.55 (0.007 sec)
# Step 2612: loss = 0.20 (0.007 sec)
# Step 2614: loss = 0.07 (0.007 sec)
# Step 2616: loss = 0.06 (0.007 sec)
# Step 2618: loss = 0.77 (0.007 sec)
# Step 2620: loss = 0.89 (0.007 sec)
# Step 2622: loss = 0.74 (0.007 sec)
# Step 2624: loss = 0.39 (0.007 sec)
# Step 2626: loss = 0.10 (0.007 sec)
# Step 2628: loss = 0.06 (0.007 sec)
# Step 2630: loss = 0.02 (0.007 sec)
# Step 2632: loss = 0.24 (0.008 sec)
# Step 2634: loss = 0.02 (0.007 sec)
# Step 2636: loss = 0.00 (0.007 sec)
# Step 2638: loss = 0.14 (0.007 sec)
# Step 2640: loss = 0.00 (0.007 sec)
# Step 2642: loss = 6.58 (0.007 sec)
# Step 2644: loss = 1.72 (0.007 sec)
# Step 2646: loss = 1.03 (0.007 sec)
# Step 2648: loss = 0.40 (0.007 sec)
# Step 2650: loss = 0.13 (0.007 sec)
# Step 2652: loss = 0.02 (0.007 sec)
# Step 2654: loss = 0.11 (0.007 sec)
# Step 2656: loss = 0.00 (0.007 sec)
# Step 2658: loss = 0.05 (0.007 sec)
# Step 2660: loss = 0.00 (0.007 sec)
# Step 2662: loss = 11.30 (0.007 sec)
# Step 2664: loss = 4.26 (0.007 sec)
# Step 2666: loss = 1.65 (0.007 sec)
# Step 2668: loss = 0.90 (0.007 sec)
# Step 2670: loss = 0.80 (0.007 sec)
# Step 2672: loss = 0.24 (0.007 sec)
# Step 2674: loss = 0.30 (0.007 sec)
# Step 2676: loss = 0.10 (0.007 sec)
# Step 2678: loss = 0.09 (0.007 sec)
# Step 2680: loss = 0.09 (0.007 sec)
# Step 2682: loss = 1.84 (0.007 sec)
# Step 2684: loss = 1.88 (0.007 sec)
# Step 2686: loss = 1.43 (0.007 sec)
# Step 2688: loss = 0.61 (0.007 sec)
# Step 2690: loss = 0.43 (0.007 sec)
# Step 2692: loss = 0.26 (0.007 sec)
# Step 2694: loss = 0.20 (0.007 sec)
# Step 2696: loss = 0.03 (0.007 sec)
# Step 2698: loss = 0.08 (0.007 sec)
# Step 2700: loss = 0.16 (0.007 sec)
# Step 2702: loss = 4.16 (0.007 sec)
# Step 2704: loss = 2.52 (0.007 sec)
# Step 2706: loss = 2.09 (0.008 sec)
# Step 2708: loss = 1.08 (0.007 sec)
# Step 2710: loss = 0.91 (0.008 sec)
# Step 2712: loss = 0.99 (0.007 sec)
# Step 2714: loss = 0.90 (0.007 sec)
# Step 2716: loss = 0.31 (0.007 sec)
# Step 2718: loss = 0.71 (0.007 sec)
# Step 2720: loss = 1.78 (0.007 sec)
# Step 2722: loss = 1.31 (0.008 sec)
# Step 2724: loss = 1.70 (0.007 sec)
# Step 2726: loss = 1.97 (0.007 sec)
# Step 2728: loss = 0.68 (0.007 sec)
# Step 2730: loss = 0.50 (0.007 sec)
# Step 2732: loss = 0.20 (0.007 sec)
# Step 2734: loss = 0.08 (0.007 sec)
# Step 2736: loss = 0.02 (0.007 sec)
# Step 2738: loss = 1.32 (0.007 sec)
# Step 2740: loss = 3.55 (0.007 sec)
# Step 2742: loss = 2.35 (0.007 sec)
# Step 2744: loss = 1.23 (0.007 sec)
# Step 2746: loss = 1.32 (0.007 sec)
# Step 2748: loss = 0.49 (0.007 sec)
# Step 2750: loss = 0.14 (0.007 sec)
# Step 2752: loss = 0.41 (0.007 sec)
# Step 2754: loss = 0.03 (0.007 sec)
# Step 2756: loss = 0.03 (0.007 sec)
# Step 2758: loss = 0.04 (0.007 sec)
# ...
# Step 11118: loss = 0.00 (0.007 sec)
# Step 11120: loss = 540.86 (0.007 sec)
# Step 11122: loss = 48.24 (0.007 sec)
# Step 11124: loss = 0.00 (0.007 sec)
# Step 11126: loss = 0.00 (0.007 sec)
# Step 11128: loss = 0.00 (0.007 sec)
# Step 11130: loss = 0.00 (0.007 sec)
# Step 11132: loss = 0.00 (0.007 sec)
# Step 11134: loss = 0.00 (0.007 sec)
# Step 11136: loss = 0.00 (0.007 sec)
# Step 11138: loss = 25.54 (0.007 sec)
# Step 11140: loss = 55.41 (0.007 sec)
# Step 11142: loss = 4.72 (0.007 sec)
# Step 11144: loss = 1.48 (0.007 sec)
# Step 11146: loss = 0.00 (0.007 sec)
# Step 11148: loss = 0.00 (0.007 sec)
# Step 11150: loss = 0.00 (0.007 sec)
# Step 11152: loss = 0.00 (0.007 sec)
# Step 11154: loss = 0.00 (0.007 sec)
# Step 11156: loss = 0.00 (0.007 sec)
# Step 11158: loss = 0.00 (0.007 sec)
# Step 11160: loss = 77.49 (0.007 sec)
# Step 11162: loss = 32.44 (0.007 sec)
# Step 11164: loss = 5.06 (0.007 sec)
# Step 11166: loss = 0.24 (0.007 sec)
# Step 11168: loss = 0.00 (0.007 sec)
# Step 11170: loss = 0.00 (0.007 sec)
# Step 11172: loss = 0.00 (0.008 sec)
# Step 11174: loss = 0.00 (0.007 sec)
# Step 11176: loss = 0.00 (0.007 sec)
# Step 11178: loss = 7.92 (0.007 sec)
# Step 11180: loss = 40.71 (0.007 sec)
# Step 11182: loss = 20.70 (0.007 sec)
# Step 11184: loss = 6.18 (0.007 sec)
# Step 11186: loss = 2.59 (0.007 sec)
# Step 11188: loss = 1.66 (0.007 sec)
# Step 11190: loss = 0.84 (0.007 sec)
# Step 11192: loss = 0.00 (0.007 sec)
# Step 11194: loss = 0.00 (0.007 sec)
# Step 11196: loss = 0.09 (0.007 sec)
# Step 11198: loss = 3.39 (0.007 sec)
# Step 11200: loss = 4.09 (0.007 sec)
# Step 11202: loss = 0.69 (0.008 sec)
# Step 11204: loss = 0.65 (0.007 sec)
# Step 11206: loss = 0.57 (0.007 sec)
# Step 11208: loss = 1.05 (0.007 sec)
# Step 11210: loss = 0.00 (0.007 sec)
# Step 11212: loss = 0.11 (0.007 sec)
# Step 11214: loss = 0.00 (0.007 sec)
# Step 11216: loss = 0.00 (0.007 sec)
# Step 11218: loss = 10.15 (0.008 sec)
# Step 11220: loss = 19.69 (0.007 sec)
# Step 11222: loss = 10.21 (0.007 sec)
# Step 11224: loss = 4.84 (0.007 sec)
# Step 11226: loss = 0.82 (0.007 sec)
# Step 11228: loss = 0.09 (0.007 sec)
# Step 11230: loss = 0.28 (0.007 sec)
# Step 11232: loss = 0.44 (0.007 sec)
# Step 11234: loss = 0.00 (0.008 sec)
# Step 11236: loss = 0.00 (0.007 sec)
# Step 11238: loss = 0.09 (0.007 sec)
# Step 11240: loss = 0.00 (0.007 sec)
# Step 11242: loss = 37.12 (0.007 sec)
# Step 11244: loss = 20.52 (0.007 sec)
# Step 11246: loss = 5.61 (0.007 sec)
# Step 11248: loss = 1.97 (0.007 sec)
# Step 11250: loss = 0.72 (0.007 sec)
# Step 11252: loss = 0.20 (0.007 sec)
# Step 11254: loss = 0.25 (0.007 sec)
# Step 11256: loss = 0.00 (0.008 sec)
# Step 11258: loss = 0.22 (0.007 sec)
# Step 11260: loss = 0.23 (0.007 sec)
# Step 11262: loss = 6.68 (0.007 sec)
# Step 11264: loss = 6.81 (0.007 sec)
# Step 11266: loss = 4.80 (0.007 sec)
# Step 11268: loss = 1.05 (0.007 sec)
# Step 11270: loss = 1.00 (0.007 sec)
# Step 11272: loss = 1.32 (0.007 sec)
# Step 11274: loss = 0.00 (0.007 sec)
# Step 11276: loss = 0.18 (0.007 sec)
# Step 11278: loss = 0.01 (0.007 sec)
# Step 11280: loss = 0.35 (0.007 sec)
# Step 11282: loss = 11.51 (0.007 sec)
# Step 11284: loss = 9.37 (0.007 sec)
# Step 11286: loss = 4.89 (0.007 sec)
# Step 11288: loss = 0.90 (0.007 sec)
# Step 11290: loss = 0.30 (0.007 sec)
# Step 11292: loss = 0.98 (0.007 sec)
# Step 11294: loss = 0.85 (0.007 sec)
# Step 11296: loss = 0.00 (0.007 sec)
# Step 11298: loss = 0.01 (0.007 sec)
# Step 11300: loss = 0.41 (0.007 sec)
# Step 11302: loss = 16.01 (0.007 sec)
# Step 11304: loss = 10.98 (0.007 sec)
# Step 11306: loss = 6.94 (0.007 sec)
# Step 11308: loss = 2.26 (0.007 sec)
# Step 11310: loss = 2.05 (0.007 sec)
# Step 11312: loss = 0.85 (0.007 sec)
# Step 11314: loss = 3.81 (0.007 sec)
# Step 11316: loss = 0.48 (0.007 sec)
# Step 11318: loss = 0.39 (0.008 sec)
# Step 11320: loss = 5.49 (0.007 sec)
# Step 11322: loss = 2.92 (0.007 sec)
# Step 11324: loss = 1.46 (0.007 sec)
# Step 11326: loss = 1.88 (0.007 sec)
# Step 11328: loss = 0.51 (0.007 sec)
# Step 11330: loss = 0.65 (0.007 sec)
# Step 11332: loss = 1.72 (0.007 sec)
# Step 11334: loss = 0.17 (0.007 sec)
# Step 11336: loss = 0.00 (0.007 sec)
# Step 11338: loss = 4.42 (0.007 sec)
# Step 11340: loss = 16.38 (0.008 sec)
# Step 11342: loss = 9.14 (0.007 sec)
# Step 11344: loss = 5.02 (0.008 sec)
# Step 11346: loss = 3.70 (0.007 sec)
# Step 11348: loss = 1.11 (0.007 sec)
# Step 11350: loss = 0.54 (0.007 sec)
# Step 11352: loss = 0.72 (0.007 sec)
# Step 11354: loss = 0.39 (0.007 sec)
# Step 11356: loss = 0.17 (0.007 sec)
# Step 11358: loss = 0.44 (0.007 sec)
# Step 11360: loss = 4.33 (0.007 sec)
# Step 11362: loss = 2.74 (0.007 sec)
# Step 11364: loss = 2.44 (0.007 sec)
# Step 11366: loss = 1.64 (0.007 sec)
# Step 11368: loss = 0.40 (0.007 sec)
# Step 11370: loss = 0.75 (0.007 sec)
# Step 11372: loss = 0.70 (0.007 sec)
# Step 11374: loss = 0.32 (0.007 sec)
# Step 11376: loss = 0.71 (0.007 sec)
# Step 11378: loss = 1.66 (0.007 sec)
# Step 11380: loss = 7.09 (0.007 sec)
# Step 11382: loss = 3.79 (0.007 sec)
# Step 11384: loss = 2.48 (0.007 sec)
# Step 11386: loss = 1.14 (0.007 sec)
# Step 11388: loss = 0.94 (0.007 sec)
# Step 11390: loss = 1.54 (0.007 sec)
# Step 11392: loss = 0.68 (0.007 sec)
# Step 11394: loss = 0.60 (0.007 sec)
# Step 11396: loss = 0.67 (0.007 sec)
# Step 11398: loss = 4.59 (0.007 sec)
# Step 11400: loss = 2.71 (0.007 sec)
# Step 11402: loss = 2.07 (0.007 sec)
# Step 11404: loss = 1.87 (0.007 sec)
# Step 11406: loss = 1.35 (0.007 sec)
# Step 11408: loss = 1.38 (0.007 sec)
# Step 11410: loss = 0.56 (0.007 sec)
# Step 11412: loss = 0.74 (0.007 sec)
# Step 11414: loss = 0.08 (0.007 sec)
# Step 11416: loss = 0.32 (0.007 sec)
# Step 11418: loss = 1.07 (0.007 sec)
# Step 11420: loss = 2.01 (0.007 sec)
# Step 11422: loss = 1.18 (0.007 sec)
# Step 11424: loss = 0.07 (0.007 sec)
# Step 11426: loss = 0.49 (0.007 sec)
# Step 11428: loss = 0.01 (0.008 sec)
# Step 11430: loss = 0.23 (0.007 sec)
# Step 11432: loss = 0.46 (0.007 sec)
# Step 11434: loss = 0.12 (0.007 sec)
# Step 11436: loss = 1.12 (0.007 sec)
# Step 11438: loss = 1.10 (0.007 sec)
# Step 11440: loss = 0.48 (0.007 sec)
# Step 11442: loss = 4.06 (0.007 sec)
# Step 11444: loss = 3.67 (0.007 sec)
# Step 11446: loss = 1.79 (0.007 sec)
# Step 11448: loss = 1.26 (0.007 sec)
# Step 11450: loss = 0.88 (0.008 sec)
# Step 11452: loss = 1.10 (0.007 sec)
# Step 11454: loss = 0.35 (0.007 sec)
# Step 11456: loss = 0.15 (0.007 sec)
# Step 11458: loss = 0.47 (0.007 sec)
# Step 11460: loss = 0.37 (0.008 sec)
# Step 11462: loss = 6.15 (0.007 sec)
# Step 11464: loss = 6.42 (0.007 sec)
# Step 11466: loss = 4.37 (0.008 sec)
# Step 11468: loss = 1.07 (0.007 sec)
# Step 11470: loss = 1.07 (0.007 sec)
# Step 11472: loss = 2.03 (0.007 sec)
# Step 11474: loss = 0.31 (0.007 sec)
# Step 11476: loss = 0.28 (0.007 sec)
# Step 11478: loss = 0.05 (0.007 sec)
# Step 11480: loss = 0.61 (0.007 sec)
# Step 11482: loss = 1.84 (0.007 sec)
# Step 11484: loss = 2.50 (0.007 sec)
# Step 11486: loss = 2.74 (0.007 sec)
# Step 11488: loss = 1.21 (0.008 sec)
# Step 11490: loss = 0.95 (0.008 sec)
# Step 11492: loss = 0.89 (0.007 sec)
# Step 11494: loss = 0.57 (0.007 sec)
# Step 11496: loss = 0.22 (0.007 sec)
# Step 11498: loss = 0.92 (0.008 sec)
# Step 11500: loss = 0.13 (0.007 sec)
# Step 11502: loss = 4.12 (0.007 sec)
# Step 11504: loss = 3.06 (0.007 sec)
# Step 11506: loss = 3.23 (0.007 sec)
# Step 11508: loss = 1.67 (0.007 sec)
# Step 11510: loss = 1.58 (0.007 sec)
# Step 11512: loss = 0.98 (0.007 sec)
# Step 11514: loss = 3.89 (0.007 sec)
# Step 11516: loss = 0.72 (0.007 sec)
# Step 11518: loss = 0.09 (0.007 sec)
# Step 11520: loss = 1.80 (0.007 sec)
# Step 11522: loss = 0.91 (0.007 sec)
# Step 11524: loss = 1.26 (0.007 sec)
# Step 11526: loss = 1.12 (0.007 sec)
# Step 11528: loss = 0.37 (0.007 sec)
# Step 11530: loss = 0.40 (0.007 sec)
# Step 11532: loss = 0.80 (0.007 sec)
# Step 11534: loss = 0.47 (0.007 sec)
# Step 11536: loss = 0.08 (0.007 sec)
# Step 11538: loss = 0.35 (0.007 sec)
# Step 11540: loss = 2.45 (0.007 sec)
# Step 11542: loss = 1.61 (0.007 sec)
# Step 11544: loss = 1.46 (0.007 sec)
# Step 11546: loss = 1.86 (0.007 sec)
# Step 11548: loss = 0.91 (0.008 sec)
# Step 11550: loss = 0.50 (0.007 sec)
# Step 11552: loss = 1.00 (0.007 sec)
# Step 11554: loss = 0.47 (0.007 sec)
# Step 11556: loss = 0.37 (0.007 sec)
# Step 11558: loss = 0.56 (0.007 sec)
# Step 11560: loss = 1.84 (0.007 sec)
# Step 11562: loss = 1.34 (0.007 sec)
# Step 11564: loss = 0.96 (0.008 sec)
# Step 11566: loss = 0.87 (0.007 sec)
# Step 11568: loss = 0.55 (0.007 sec)
# Step 11570: loss = 0.43 (0.007 sec)
# Step 11572: loss = 0.43 (0.007 sec)
# Step 11574: loss = 0.14 (0.007 sec)
# Step 11576: loss = 0.51 (0.007 sec)
# Step 11578: loss = 0.43 (0.007 sec)
# Step 11580: loss = 1.39 (0.008 sec)
# Step 11582: loss = 0.51 (0.007 sec)
# Step 11584: loss = 1.07 (0.007 sec)
# Step 11586: loss = 0.75 (0.007 sec)
# Step 11588: loss = 0.37 (0.007 sec)
# Step 11590: loss = 1.21 (0.007 sec)
# Step 11592: loss = 0.60 (0.007 sec)
# Step 11594: loss = 0.57 (0.007 sec)
# Step 11596: loss = 0.64 (0.007 sec)
# Step 11598: loss = 1.69 (0.007 sec)
# Step 11600: loss = 1.23 (0.007 sec)
# Step 11602: loss = 0.60 (0.007 sec)
# Step 11604: loss = 0.46 (0.007 sec)
# Step 11606: loss = 0.78 (0.007 sec)
# Step 11608: loss = 0.97 (0.007 sec)
# Step 11610: loss = 0.44 (0.007 sec)
# Step 11612: loss = 0.41 (0.008 sec)
# Step 11614: loss = 0.41 (0.007 sec)
# Step 11616: loss = 0.52 (0.007 sec)
# Step 11618: loss = 0.67 (0.007 sec)
# Step 11620: loss = 0.79 (0.007 sec)
# Step 11622: loss = 0.30 (0.007 sec)
# Step 11624: loss = 0.01 (0.007 sec)
# Step 11626: loss = 0.15 (0.007 sec)
# Step 11628: loss = 0.02 (0.007 sec)
# Step 11630: loss = 0.23 (0.007 sec)
# Step 11632: loss = 0.29 (0.007 sec)
# Step 11634: loss = 0.12 (0.007 sec)
# Step 11636: loss = 0.93 (0.007 sec)
# Step 11638: loss = 0.88 (0.007 sec)
# Step 11640: loss = 0.32 (0.007 sec)
# Step 11642: loss = 1.19 (0.008 sec)
# Step 11644: loss = 0.88 (0.007 sec)
# Step 11646: loss = 0.47 (0.007 sec)
# Step 11648: loss = 0.46 (0.007 sec)
# Step 11650: loss = 0.42 (0.007 sec)
# Step 11652: loss = 0.42 (0.007 sec)
# Step 11654: loss = 0.29 (0.007 sec)
# Step 11656: loss = 0.14 (0.007 sec)
# Step 11658: loss = 0.47 (0.007 sec)
# Step 11660: loss = 0.33 (0.007 sec)
# Step 11662: loss = 1.64 (0.007 sec)
# Step 11664: loss = 1.95 (0.007 sec)
# Step 11666: loss = 1.91 (0.007 sec)
# Step 11668: loss = 0.65 (0.007 sec)
# Step 11670: loss = 1.20 (0.008 sec)
# Step 11672: loss = 1.45 (0.007 sec)
# Step 11674: loss = 0.67 (0.007 sec)
# Step 11676: loss = 0.32 (0.007 sec)
# Step 11678: loss = 0.18 (0.007 sec)
# Step 11680: loss = 0.45 (0.007 sec)
# Step 11682: loss = 0.28 (0.007 sec)
# Step 11684: loss = 0.53 (0.007 sec)
# Step 11686: loss = 0.84 (0.007 sec)
# Step 11688: loss = 0.37 (0.007 sec)
# Step 11690: loss = 0.43 (0.007 sec)
# Step 11692: loss = 0.34 (0.007 sec)
# Step 11694: loss = 0.26 (0.007 sec)
# Step 11696: loss = 0.22 (0.007 sec)
# Step 11698: loss = 0.27 (0.007 sec)
# Step 11700: loss = 0.16 (0.007 sec)
# Step 11702: loss = 0.55 (0.008 sec)
# Step 11704: loss = 0.29 (0.008 sec)
# Step 11706: loss = 0.53 (0.007 sec)
# Step 11708: loss = 0.47 (0.007 sec)
# Step 11710: loss = 0.73 (0.007 sec)
# Step 11712: loss = 0.49 (0.007 sec)
# Step 11714: loss = 2.34 (0.007 sec)
# Step 11716: loss = 0.42 (0.007 sec)
# Step 11718: loss = 0.14 (0.008 sec)
# Step 11720: loss = 0.49 (0.007 sec)
# Step 11722: loss = 0.18 (0.007 sec)
# Step 11724: loss = 0.47 (0.007 sec)
# Step 11726: loss = 0.77 (0.007 sec)
# Step 11728: loss = 0.20 (0.007 sec)
# Step 11730: loss = 0.30 (0.008 sec)
# Step 11732: loss = 0.57 (0.008 sec)
# Step 11734: loss = 0.39 (0.007 sec)
# Step 11736: loss = 0.09 (0.007 sec)
# Step 11738: loss = 0.48 (0.007 sec)
# Step 11740: loss = 0.56 (0.007 sec)
# Step 11742: loss = 0.44 (0.007 sec)
# Step 11744: loss = 0.63 (0.008 sec)
# Step 11746: loss = 0.84 (0.007 sec)
# Step 11748: loss = 0.38 (0.007 sec)
# Step 11750: loss = 0.28 (0.007 sec)
# Step 11752: loss = 0.56 (0.007 sec)
# Step 11754: loss = 0.41 (0.007 sec)
# Step 11756: loss = 0.31 (0.008 sec)
# Step 11758: loss = 0.27 (0.007 sec)
# Step 11760: loss = 1.72 (0.007 sec)
# Step 11762: loss = 1.08 (0.007 sec)
# Step 11764: loss = 0.93 (0.007 sec)
# Step 11766: loss = 0.83 (0.007 sec)
# Step 11768: loss = 0.81 (0.007 sec)
# Step 11770: loss = 0.54 (0.008 sec)
# Step 11772: loss = 0.60 (0.007 sec)
# Step 11774: loss = 0.30 (0.007 sec)
# Step 11776: loss = 0.51 (0.007 sec)
# Step 11778: loss = 0.50 (0.007 sec)
# Step 11780: loss = 0.24 (0.007 sec)
# Step 11782: loss = 0.18 (0.007 sec)
# Step 11784: loss = 0.39 (0.007 sec)
# Step 11786: loss = 0.22 (0.007 sec)
# Step 11788: loss = 0.19 (0.007 sec)
# Step 11790: loss = 0.72 (0.007 sec)
# Step 11792: loss = 0.14 (0.007 sec)
# Step 11794: loss = 0.30 (0.007 sec)
# Step 11796: loss = 0.37 (0.007 sec)
# Step 11798: loss = 0.23 (0.007 sec)
# Step 11800: loss = 0.25 (0.007 sec)
# Step 11802: loss = 0.24 (0.007 sec)
# Step 11804: loss = 0.18 (0.007 sec)
# Step 11806: loss = 0.45 (0.007 sec)
# Step 11808: loss = 0.57 (0.007 sec)
# Step 11810: loss = 0.26 (0.007 sec)
# Step 11812: loss = 0.24 (0.007 sec)
# Step 11814: loss = 0.37 (0.007 sec)
# Step 11816: loss = 0.37 (0.007 sec)
# Step 11818: loss = 0.44 (0.007 sec)
# Step 11820: loss = 0.27 (0.007 sec)
# Step 11822: loss = 0.08 (0.007 sec)
# Step 11824: loss = 0.00 (0.007 sec)
# Step 11826: loss = 0.00 (0.007 sec)
# Step 11828: loss = 0.02 (0.007 sec)
# Step 11830: loss = 0.10 (0.007 sec)
# Step 11832: loss = 0.22 (0.007 sec)
# Step 11834: loss = 0.04 (0.007 sec)
# Step 11836: loss = 0.40 (0.007 sec)
# Step 11838: loss = 0.49 (0.007 sec)
# Step 11840: loss = 0.20 (0.007 sec)
# Step 11842: loss = 0.66 (0.007 sec)
# Step 11844: loss = 0.38 (0.007 sec)
# Step 11846: loss = 0.29 (0.007 sec)
# Step 11848: loss = 0.25 (0.007 sec)
# Step 11850: loss = 0.16 (0.007 sec)
# Step 11852: loss = 0.23 (0.007 sec)
# Step 11854: loss = 0.15 (0.007 sec)
# Step 11856: loss = 0.11 (0.007 sec)
# Step 11858: loss = 0.15 (0.007 sec)
# Step 11860: loss = 0.21 (0.008 sec)
# Step 11862: loss = 0.42 (0.007 sec)
# Step 11864: loss = 0.58 (0.007 sec)
# Step 11866: loss = 0.47 (0.007 sec)
# Step 11868: loss = 0.29 (0.007 sec)
# Step 11870: loss = 0.60 (0.007 sec)
# Step 11872: loss = 0.70 (0.007 sec)
# Step 11874: loss = 0.53 (0.007 sec)
# Step 11876: loss = 0.36 (0.007 sec)
# Step 11878: loss = 0.25 (0.007 sec)
# Step 11880: loss = 0.51 (0.008 sec)
# Step 11882: loss = 0.12 (0.008 sec)
# Step 11884: loss = 0.18 (0.007 sec)
# Step 11886: loss = 0.44 (0.007 sec)
# Step 11888: loss = 0.19 (0.007 sec)
# Step 11890: loss = 0.10 (0.007 sec)
# Step 11892: loss = 0.05 (0.007 sec)
# Step 11894: loss = 0.18 (0.008 sec)
# Step 11896: loss = 0.05 (0.007 sec)
# Step 11898: loss = 0.17 (0.007 sec)
# Step 11900: loss = 0.17 (0.007 sec)
# Step 11902: loss = 0.23 (0.007 sec)
# Step 11904: loss = 0.12 (0.007 sec)
# Step 11906: loss = 0.27 (0.007 sec)
# Step 11908: loss = 0.27 (0.008 sec)
# Step 11910: loss = 0.19 (0.007 sec)
# Step 11912: loss = 0.15 (0.007 sec)
# Step 11914: loss = 1.24 (0.007 sec)
# Step 11916: loss = 0.11 (0.007 sec)
# Step 11918: loss = 0.04 (0.007 sec)
# Step 11920: loss = 0.21 (0.007 sec)
# Step 11922: loss = 0.02 (0.007 sec)
# Step 11924: loss = 0.05 (0.007 sec)
# Step 11926: loss = 0.29 (0.007 sec)
# Step 11928: loss = 0.03 (0.007 sec)
# Step 11930: loss = 0.08 (0.007 sec)
# Step 11932: loss = 0.32 (0.007 sec)
# Step 11934: loss = 0.20 (0.007 sec)
# Step 11936: loss = 0.06 (0.007 sec)
# Step 11938: loss = 0.21 (0.007 sec)
# Step 11940: loss = 0.20 (0.007 sec)
# Step 11942: loss = 0.10 (0.007 sec)
# Step 11944: loss = 0.24 (0.007 sec)
# Step 11946: loss = 0.12 (0.007 sec)
# Step 11948: loss = 0.23 (0.007 sec)
# Step 11950: loss = 0.12 (0.007 sec)
# Step 11952: loss = 0.20 (0.007 sec)
# Step 11954: loss = 0.19 (0.007 sec)
# Step 11956: loss = 0.15 (0.007 sec)
# Step 11958: loss = 0.06 (0.007 sec)
# Step 11960: loss = 0.59 (0.007 sec)
# Step 11962: loss = 0.44 (0.007 sec)
# Step 11964: loss = 0.42 (0.007 sec)
# Step 11966: loss = 0.26 (0.007 sec)
# Step 11968: loss = 0.38 (0.007 sec)
# Step 11970: loss = 0.41 (0.007 sec)
# Step 11972: loss = 0.34 (0.007 sec)
# Step 11974: loss = 0.12 (0.007 sec)
# Step 11976: loss = 0.27 (0.007 sec)
# Step 11978: loss = 0.32 (0.007 sec)
# Step 11980: loss = 0.16 (0.007 sec)
# Step 11982: loss = 0.12 (0.007 sec)
# Step 11984: loss = 0.18 (0.007 sec)
# Step 11986: loss = 0.14 (0.007 sec)
# Step 11988: loss = 0.15 (0.007 sec)
# Step 11990: loss = 0.48 (0.007 sec)
# Step 11992: loss = 0.13 (0.007 sec)
# Step 11994: loss = 0.24 (0.007 sec)
# Step 11996: loss = 0.27 (0.007 sec)
# Step 11998: loss = 0.12 (0.007 sec)
# Training Data Eval:
#   Num examples: 10000  Num correct: 9680  Precision @1.00: 0.9680

# %% [markdown]
# <h2>Conclusion</h2>
# <p>Usually this creates a classifier with training set precision in the 90's</p>
